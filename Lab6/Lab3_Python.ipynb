# %% [markdown]
# # Regular expresion and Reshape

# %%
import pandas as pd
import numpy as np
import chardet # to get string character format 
import re

# %%
panel = pd.read_stata("../../data/ENAHO/panel_2016_2018.dta")
# Out:
# C:\Users\Roberto\anaconda3\lib\site-packages\pandas\io\stata.py:1514: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   warnings.warn(msg, UnicodeWarning)

# %%
panel
# Out:
#      conglome vivienda aÑo_16 mes_16 nconglome_16 conglome_16 vivienda_16  \
# 0      005012      039   2016     01       007083      005012         039
# 1      005012      025   2016     01       007083      005012         025
# 2      005012      012   2016     01       007083      005012         012
# 3      005017      075   2016     05       007093      005017         075
# 4      005017      008   2016     05       007093      005017         008
# ...       ...      ...    ...    ...          ...         ...         ...
# 1934   010360      063   2016     11       008793      010360         063
# 1935   010360      064   2016     11       008793      010360         064
# 1936   010360      142   2016     11       008793      010360         142
# 1937   010360      144   2016     11       008793      010360         144
# 1938   010370      103   2016     01       044447      010370         103
#
#      hogar_16 ubigeo_16    dominio_16  ...    linea_20  pobreza_20  \
# 0          11    010101  sierra norte  ...  303.520996    no pobre
# 1          11    010101  sierra norte  ...  303.520996    no pobre
# 2          11    010101  sierra norte  ...  303.520996    no pobre
# 3          11    010101  sierra norte  ...  303.520996    no pobre
# 4          11    010101  sierra norte  ...  303.520996    no pobre
# ...       ...       ...           ...  ...         ...         ...
# 1934       11    220504         selva  ...  247.342163    no pobre
# 1935       11    220504         selva  ...  247.342163    no pobre
# 1936       11    220504         selva  ...  247.342163    no pobre
# 1937       11    220504         selva  ...  247.342163    no pobre
# 1938       11    230101     costa sur  ...  359.276611    no pobre
#
#                                     tipocuestionario_20  tipoentrevista_20  \
# 0     cuestionario reducido - durante la emergencia ...         telefónico
# 1     cuestionario reducido - durante la emergencia ...         telefónico
# 2     cuestionario reducido - durante la emergencia ...         telefónico
# 3     cuestionario reducido - durante la emergencia ...         telefónico
# 4     cuestionario reducido - durante la emergencia ...         telefónico
# ...                                                 ...                ...
# 1934  cuestionario completo - durante la emergencia ...         presencial
# 1935  cuestionario completo - durante la emergencia ...         presencial
# 1936  cuestionario completo - durante la emergencia ...         presencial
# 1937  cuestionario completo - durante la emergencia ...         presencial
# 1938  cuestionario completo - antes de la emergencia...         presencial
#
#       factor07_20  nconglome_20  sub_conglome_20  lineav_rpl_20   lineav_20  \
# 0       39.763752        007083               00            657  553.222473
# 1       39.763752        007083               00            657  546.850037
# 2       39.763752        007083               00            657  561.609619
# 3       55.669254        007093               00            657  559.775146
# 4       55.669254        007093               00            657  563.189392
# ...           ...           ...              ...            ...         ...
# 1934   111.686325        008793               00            657  569.045166
# 1935   111.686325        008793               00            657  576.689819
# 1936   111.686325        008793               00            657  573.543945
# 1937   111.686325        008793               00            657  571.337524
# 1938     6.529222        044447               00            657  590.305908
#
#               pobrezav_20
# 0           no vulnerable
# 1           no vulnerable
# 2     vulnerable no pobre
# 3     vulnerable no pobre
# 4           no vulnerable
# ...                   ...
# 1934  vulnerable no pobre
# 1935  vulnerable no pobre
# 1936  vulnerable no pobre
# 1937        no vulnerable
# 1938        no vulnerable
#
# [1939 rows x 804 columns]

# %%
panel.columns = map(str.lower, panel.columns)  # any capittal letter to lower

# %%
panel.rename(columns = {'año_16':'year_16', 'año_17':'year_17', 'año_18':'year_18', 'año_19':'year_19',
                       'año_20':'year_20'}, inplace = True)

# %%
# rename hogar_16 to build a identifier per household 

panel.rename(columns = {'hogar_16':'hogar'}, inplace = True)

# %%
panel.rename(columns = {'conglome':'cong', 'vivienda':'viv', 'hogar':'hog'}, inplace = True)

# %%
panel
# Out:
#         cong  viv year_16 mes_16 nconglome_16 conglome_16 vivienda_16 hog  \
# 0     005012  039    2016     01       007083      005012         039  11
# 1     005012  025    2016     01       007083      005012         025  11
# 2     005012  012    2016     01       007083      005012         012  11
# 3     005017  075    2016     05       007093      005017         075  11
# 4     005017  008    2016     05       007093      005017         008  11
# ...      ...  ...     ...    ...          ...         ...         ...  ..
# 1934  010360  063    2016     11       008793      010360         063  11
# 1935  010360  064    2016     11       008793      010360         064  11
# 1936  010360  142    2016     11       008793      010360         142  11
# 1937  010360  144    2016     11       008793      010360         144  11
# 1938  010370  103    2016     01       044447      010370         103  11
#
#      ubigeo_16    dominio_16  ...    linea_20  pobreza_20  \
# 0       010101  sierra norte  ...  303.520996    no pobre
# 1       010101  sierra norte  ...  303.520996    no pobre
# 2       010101  sierra norte  ...  303.520996    no pobre
# 3       010101  sierra norte  ...  303.520996    no pobre
# 4       010101  sierra norte  ...  303.520996    no pobre
# ...        ...           ...  ...         ...         ...
# 1934    220504         selva  ...  247.342163    no pobre
# 1935    220504         selva  ...  247.342163    no pobre
# 1936    220504         selva  ...  247.342163    no pobre
# 1937    220504         selva  ...  247.342163    no pobre
# 1938    230101     costa sur  ...  359.276611    no pobre
#
#                                     tipocuestionario_20  tipoentrevista_20  \
# 0     cuestionario reducido - durante la emergencia ...         telefónico
# 1     cuestionario reducido - durante la emergencia ...         telefónico
# 2     cuestionario reducido - durante la emergencia ...         telefónico
# 3     cuestionario reducido - durante la emergencia ...         telefónico
# 4     cuestionario reducido - durante la emergencia ...         telefónico
# ...                                                 ...                ...
# 1934  cuestionario completo - durante la emergencia ...         presencial
# 1935  cuestionario completo - durante la emergencia ...         presencial
# 1936  cuestionario completo - durante la emergencia ...         presencial
# 1937  cuestionario completo - durante la emergencia ...         presencial
# 1938  cuestionario completo - antes de la emergencia...         presencial
#
#       factor07_20  nconglome_20  sub_conglome_20  lineav_rpl_20   lineav_20  \
# 0       39.763752        007083               00            657  553.222473
# 1       39.763752        007083               00            657  546.850037
# 2       39.763752        007083               00            657  561.609619
# 3       55.669254        007093               00            657  559.775146
# 4       55.669254        007093               00            657  563.189392
# ...           ...           ...              ...            ...         ...
# 1934   111.686325        008793               00            657  569.045166
# 1935   111.686325        008793               00            657  576.689819
# 1936   111.686325        008793               00            657  573.543945
# 1937   111.686325        008793               00            657  571.337524
# 1938     6.529222        044447               00            657  590.305908
#
#               pobrezav_20
# 0           no vulnerable
# 1           no vulnerable
# 2     vulnerable no pobre
# 3     vulnerable no pobre
# 4           no vulnerable
# ...                   ...
# 1934  vulnerable no pobre
# 1935  vulnerable no pobre
# 1936  vulnerable no pobre
# 1937        no vulnerable
# 1938        no vulnerable
#
# [1939 rows x 804 columns]

# %%
panel['linea_19']
# Out:
# 0       302.621338
# 1       302.621338
# 2       302.621338
# 3       302.621338
# 4       302.621338
#            ...
# 1934    244.336487
# 1935    244.336487
# 1936    244.336487
# 1937    244.336487
# 1938    349.202942
# Name: linea_19, Length: 1939, dtype: float32

# %%
list(panel.columns)
# Out:
# ['cong',
#  'viv',
#  'year_16',
#  'mes_16',
#  'nconglome_16',
#  'conglome_16',
#  'vivienda_16',
#  'hog',
#  'ubigeo_16',
#  'dominio_16',
#  'percepho_16',
#  'gru52hd2_16',
#  'ingpeihd_16',
#  'mieperho_16',
#  'totmieho_16',
#  'ia01hd_16',
#  'ia02hd_16',
#  'ingbruhd_16',
#  'ingnethd_16',
#  'pagesphd_16',
#  'ingindhd_16',
#  'ingauthd_16',
#  'insedthd_16',
#  'insedlhd_16',
#  'paesechd_16',
#  'ingseihd_16',
#  'isecauhd_16',
#  'ingexthd_16',
#  'ingtrahd_16',
#  'ingtexhd_16',
#  'ingrenhd_16',
#  'ingoexhd_16',
#  'g05hd_16',
#  'ig06hd_16',
#  'g05hd1_16',
#  'ig06hd1_16',
#  'g05hd2_16',
#  'ig06hd2_16',
#  'g05hd3_16',
#  'ig06hd3_16',
#  'g05hd4_16',
#  'ig06hd4_16',
#  'g05hd5_16',
#  'ig06hd5_16',
#  'g05hd6_16',
#  'ig06hd6_16',
#  'g07hd_16',
#  'ig08hd_16',
#  'ig03hd1_16',
#  'ig03hd2_16',
#  'ig03hd3_16',
#  'ig03hd4_16',
#  'sg23_16',
#  'sig24_16',
#  'sg25_16',
#  'sig26_16',
#  'ga03hd_16',
#  'ga04hd_16',
#  'sg42_16',
#  'sg42d_16',
#  'sg421_16',
#  'sg42d1_16',
#  'sg422_16',
#  'sg42d2_16',
#  'sg423_16',
#  'sg42d3_16',
#  'ingtprhd_16',
#  'ingtpuhd_16',
#  'ingtpu01_16',
#  'ingtpu02_16',
#  'ingtpu03_16',
#  'ingtpu04_16',
#  'ingtpu05_16',
#  'gru11hd_16',
#  'gru12hd1_16',
#  'gru12hd2_16',
#  'gru13hd1_16',
#  'gru13hd2_16',
#  'gru13hd3_16',
#  'gru13hd4_16',
#  'gru14hd_16',
#  'gru14hd1_16',
#  'gru14hd2_16',
#  'gru14hd3_16',
#  'gru14hd4_16',
#  'gru14hd5_16',
#  'gru14hd6_16',
#  'gru21hd_16',
#  'gru22hd1_16',
#  'gru22hd2_16',
#  'gru23hd1_16',
#  'gru23hd2_16',
#  'gru23hd3_16',
#  'gru24hd_16',
#  'gru31hd_16',
#  'gru32hd1_16',
#  'gru32hd2_16',
#  'gru33hd1_16',
#  'gru33hd2_16',
#  'gru33hd3_16',
#  'gru34hd_16',
#  'gru41hd_16',
#  'gru42hd1_16',
#  'gru42hd2_16',
#  'gru43hd1_16',
#  'gru43hd2_16',
#  'gru43hd3_16',
#  'gru44hd_16',
#  'gru51hd_16',
#  'gru52hd1_16',
#  'gru53hd1_16',
#  'gru53hd2_16',
#  'gru53hd3_16',
#  'gru53hd4_16',
#  'gru54hd_16',
#  'gru61hd_16',
#  'gru62hd1_16',
#  'gru62hd2_16',
#  'gru63hd1_16',
#  'gru63hd2_16',
#  'gru63hd3_16',
#  'gru64hd_16',
#  'gru71hd_16',
#  'gru72hd1_16',
#  'gru72hd2_16',
#  'gru73hd1_16',
#  'gru73hd2_16',
#  'gru73hd3_16',
#  'gru74hd_16',
#  'gru81hd_16',
#  'gru82hd1_16',
#  'gru82hd2_16',
#  'gru83hd1_16',
#  'gru83hd2_16',
#  'gru83hd3_16',
#  'gru83hd4_16',
#  'gru84hd_16',
#  'gru84hd1_16',
#  'gru85hd1_16',
#  'gru86hd1_16',
#  'gru86hd2_16',
#  'gru87hd_16',
#  'ingotrhd_16',
#  'ingmo1hd_16',
#  'ingmo2hd_16',
#  'inghog1d_16',
#  'inghog2d_16',
#  'gashog1d_16',
#  'gashog2d_16',
#  'linpe_16',
#  'linea_16',
#  'pobreza_16',
#  'ld_16',
#  'factor07_16',
#  'estrsocial_16',
#  'year_17',
#  'mes_17',
#  'nconglome_17',
#  'conglome_17',
#  'vivienda_17',
#  'hogar_17',
#  'ubigeo_17',
#  'dominio_17',
#  'percepho_17',
#  'mieperho_17',
#  'totmieho_17',
#  'ia01hd_17',
#  'ia02hd_17',
#  'ingbruhd_17',
#  'ingnethd_17',
#  'pagesphd_17',
#  'ingindhd_17',
#  'ingauthd_17',
#  'insedthd_17',
#  'insedlhd_17',
#  'paesechd_17',
#  'ingseihd_17',
#  'isecauhd_17',
#  'ingexthd_17',
#  'ingtrahd_17',
#  'ingtexhd_17',
#  'ingrenhd_17',
#  'ingoexhd_17',
#  'g05hd_17',
#  'ig06hd_17',
#  'g05hd1_17',
#  'ig06hd1_17',
#  'g05hd2_17',
#  'ig06hd2_17',
#  'g05hd3_17',
#  'ig06hd3_17',
#  'g05hd4_17',
#  'ig06hd4_17',
#  'g05hd5_17',
#  'ig06hd5_17',
#  'g05hd6_17',
#  'ig06hd6_17',
#  'g07hd_17',
#  'ig08hd_17',
#  'ig03hd1_17',
#  'ig03hd2_17',
#  'ig03hd3_17',
#  'ig03hd4_17',
#  'sg23_17',
#  'sig24_17',
#  'sg25_17',
#  'sig26_17',
#  'ga03hd_17',
#  'ga04hd_17',
#  'sg42_17',
#  'sg42d_17',
#  'sg421_17',
#  'sg42d1_17',
#  'sg422_17',
#  'sg42d2_17',
#  'sg423_17',
#  'sg42d3_17',
#  'ingtprhd_17',
#  'ingtpuhd_17',
#  'ingtpu01_17',
#  'ingtpu02_17',
#  'ingtpu03_17',
#  'ingtpu04_17',
#  'ingtpu05_17',
#  'gru11hd_17',
#  'gru12hd1_17',
#  'gru12hd2_17',
#  'gru13hd1_17',
#  'gru13hd2_17',
#  'gru13hd3_17',
#  'gru13hd4_17',
#  'gru14hd_17',
#  'gru14hd1_17',
#  'gru14hd2_17',
#  'gru14hd3_17',
#  'gru14hd4_17',
#  'gru14hd5_17',
#  'gru14hd6_17',
#  'gru21hd_17',
#  'gru22hd1_17',
#  'gru22hd2_17',
#  'gru23hd1_17',
#  'gru23hd2_17',
#  'gru23hd3_17',
#  'gru24hd_17',
#  'gru31hd_17',
#  'gru32hd1_17',
#  'gru32hd2_17',
#  'gru33hd1_17',
#  'gru33hd2_17',
#  'gru33hd3_17',
#  'gru34hd_17',
#  'gru41hd_17',
#  'gru42hd1_17',
#  'gru42hd2_17',
#  'gru43hd1_17',
#  'gru43hd2_17',
#  'gru43hd3_17',
#  'gru44hd_17',
#  'gru51hd_17',
#  'gru52hd1_17',
#  'gru53hd1_17',
#  'gru53hd2_17',
#  'gru53hd3_17',
#  'gru53hd4_17',
#  'gru54hd_17',
#  'gru61hd_17',
#  'gru62hd1_17',
#  'gru62hd2_17',
#  'gru63hd1_17',
#  'gru63hd2_17',
#  'gru63hd3_17',
#  'gru64hd_17',
#  'gru71hd_17',
#  'gru72hd1_17',
#  'gru72hd2_17',
#  'gru73hd1_17',
#  'gru73hd2_17',
#  'gru73hd3_17',
#  'gru74hd_17',
#  'gru81hd_17',
#  'gru82hd1_17',
#  'gru82hd2_17',
#  'gru83hd1_17',
#  'gru83hd2_17',
#  'gru83hd3_17',
#  'gru83hd4_17',
#  'gru84hd_17',
#  'gru84hd1_17',
#  'gru85hd1_17',
#  'gru86hd1_17',
#  'gru86hd2_17',
#  'gru87hd_17',
#  'ingotrhd_17',
#  'ingmo1hd_17',
#  'ingmo2hd_17',
#  'inghog1d_17',
#  'inghog2d_17',
#  'gashog1d_17',
#  'gashog21_17',
#  'gashog22_17',
#  'gashog23_17',
#  'gashog24_17',
#  'gashog26_17',
#  'gashog25_17',
#  'gashog2d_17',
#  'ld_17',
#  'linpe_17',
#  'linea_17',
#  'pobreza_17',
#  'estrsocial_17',
#  'factor07_17',
#  'year_18',
#  'mes_18',
#  'nconglome_18',
#  'conglome_18',
#  'vivienda_18',
#  'hogar_18',
#  'ubigeo_18',
#  'dominio_18',
#  'percepho_18',
#  'mieperho_18',
#  'totmieho_18',
#  'ia01hd_18',
#  'ia02hd_18',
#  'ig03hd1_18',
#  'ig03hd2_18',
#  'ig03hd3_18',
#  'ig03hd4_18',
#  'ga03hd_18',
#  'ga04hd_18',
#  'sg23_18',
#  'sig24_18',
#  'sg25_18',
#  'sig26_18',
#  'sg42_18',
#  'sg421_18',
#  'sg422_18',
#  'sg423_18',
#  'sg42d_18',
#  'sg42d1_18',
#  'sg42d2_18',
#  'sg42d3_18',
#  'ingbruhd_18',
#  'ingnethd_18',
#  'pagesphd_18',
#  'ingindhd_18',
#  'ingauthd_18',
#  'insedthd_18',
#  'insedlhd_18',
#  'paesechd_18',
#  'ingseihd_18',
#  'isecauhd_18',
#  'ingexthd_18',
#  'ingtrahd_18',
#  'ingtexhd_18',
#  'ingrenhd_18',
#  'ingoexhd_18',
#  'g05hd_18',
#  'ig06hd_18',
#  'g05hd1_18',
#  'ig06hd1_18',
#  'g05hd2_18',
#  'ig06hd2_18',
#  'g05hd3_18',
#  'ig06hd3_18',
#  'g05hd4_18',
#  'ig06hd4_18',
#  'g05hd5_18',
#  'ig06hd5_18',
#  'g05hd6_18',
#  'ig06hd6_18',
#  'g07hd_18',
#  'ig08hd_18',
#  'ingtprhd_18',
#  'ingtpuhd_18',
#  'ingtpu01_18',
#  'ingtpu02_18',
#  'ingtpu03_18',
#  'ingtpu04_18',
#  'ingtpu05_18',
#  'gru11hd_18',
#  'gru12hd1_18',
#  'gru12hd2_18',
#  'gru13hd1_18',
#  'gru13hd2_18',
#  'gru13hd3_18',
#  'gru13hd4_18',
#  'gru14hd_18',
#  'gru14hd1_18',
#  'gru14hd2_18',
#  'gru14hd3_18',
#  'gru14hd4_18',
#  'gru14hd5_18',
#  'gru14hd6_18',
#  'gru21hd_18',
#  'gru22hd1_18',
#  'gru22hd2_18',
#  'gru23hd1_18',
#  'gru23hd2_18',
#  'gru23hd3_18',
#  'gru24hd_18',
#  'gru31hd_18',
#  'gru32hd1_18',
#  'gru32hd2_18',
#  'gru33hd1_18',
#  'gru33hd2_18',
#  'gru33hd3_18',
#  'gru34hd_18',
#  'gru41hd_18',
#  'gru42hd1_18',
#  'gru42hd2_18',
#  'gru43hd1_18',
#  'gru43hd2_18',
#  'gru43hd3_18',
#  'gru44hd_18',
#  'gru51hd_18',
#  'gru52hd1_18',
#  'gru53hd1_18',
#  'gru53hd2_18',
#  'gru53hd3_18',
#  'gru53hd4_18',
#  'gru54hd_18',
#  'gru61hd_18',
#  'gru62hd1_18',
#  'gru62hd2_18',
#  'gru63hd1_18',
#  'gru63hd2_18',
#  'gru63hd3_18',
#  'gru64hd_18',
#  'gru71hd_18',
#  'gru72hd1_18',
#  'gru72hd2_18',
#  'gru73hd1_18',
#  'gru73hd2_18',
#  'gru73hd3_18',
#  'gru74hd_18',
#  'gru81hd_18',
#  'gru82hd1_18',
#  'gru82hd2_18',
#  'gru83hd1_18',
#  'gru83hd2_18',
#  'gru83hd3_18',
#  'gru83hd4_18',
#  'gru84hd_18',
#  'gru84hd1_18',
#  'gru85hd1_18',
#  'gru86hd1_18',
#  'gru86hd2_18',
#  'gru87hd_18',
#  'ingotrhd_18',
#  'ingmo1hd_18',
#  'ingmo2hd_18',
#  'inghog1d_18',
#  'inghog2d_18',
#  'gashog1d_18',
#  'gashog21_18',
#  'gashog22_18',
#  'gashog23_18',
#  'gashog24_18',
#  'gashog26_18',
#  'gashog25_18',
#  'gashog2d_18',
#  'ld_18',
#  'estrsocial_18',
#  'linpe_18',
#  'linea_18',
#  'pobreza_18',
#  'factor07_18',
#  'year_19',
#  'mes_19',
#  'nconglome_19',
#  'conglome_19',
#  'vivienda_19',
#  'hogar_19',
#  'ubigeo_19',
#  'dominio_19',
#  'percepho_19',
#  'mieperho_19',
#  'totmieho_19',
#  'ia01hd_19',
#  'ia02hd_19',
#  'ig03hd1_19',
#  'ig03hd2_19',
#  'ig03hd3_19',
#  'ig03hd4_19',
#  'ga03hd_19',
#  'ga04hd_19',
#  'sg23_19',
#  'sig24_19',
#  'sg25_19',
#  'sig26_19',
#  'sg42_19',
#  'sg421_19',
#  'sg422_19',
#  'sg423_19',
#  'sg42d_19',
#  'sg42d1_19',
#  'sg42d2_19',
#  'sg42d3_19',
#  'ingbruhd_19',
#  'ingnethd_19',
#  'pagesphd_19',
#  'ingindhd_19',
#  'ingauthd_19',
#  'insedthd_19',
#  'insedlhd_19',
#  'paesechd_19',
#  'ingseihd_19',
#  'isecauhd_19',
#  'ingexthd_19',
#  'ingtrahd_19',
#  'ingtexhd_19',
#  'ingrenhd_19',
#  'ingoexhd_19',
#  'g05hd_19',
#  'ig06hd_19',
#  'g05hd1_19',
#  'ig06hd1_19',
#  'g05hd2_19',
#  'ig06hd2_19',
#  'g05hd3_19',
#  'ig06hd3_19',
#  'g05hd4_19',
#  'ig06hd4_19',
#  'g05hd5_19',
#  'ig06hd5_19',
#  'g05hd6_19',
#  'ig06hd6_19',
#  'g07hd_19',
#  'ig08hd_19',
#  'ingtprhd_19',
#  'ingtpuhd_19',
#  'ingtpu01_19',
#  'ingtpu02_19',
#  'ingtpu03_19',
#  'ingtpu04_19',
#  'ingtpu05_19',
#  'gru11hd_19',
#  'gru12hd1_19',
#  'gru12hd2_19',
#  'gru13hd1_19',
#  'gru13hd2_19',
#  'gru13hd3_19',
#  'gru13hd4_19',
#  'gru14hd_19',
#  'gru14hd1_19',
#  'gru14hd2_19',
#  'gru14hd3_19',
#  'gru14hd4_19',
#  'gru14hd5_19',
#  'gru14hd6_19',
#  'gru21hd_19',
#  'gru22hd1_19',
#  'gru22hd2_19',
#  'gru23hd1_19',
#  'gru23hd2_19',
#  'gru23hd3_19',
#  'gru24hd_19',
#  'gru31hd_19',
#  'gru32hd1_19',
#  'gru32hd2_19',
#  'gru33hd1_19',
#  'gru33hd2_19',
#  'gru33hd3_19',
#  'gru34hd_19',
#  'gru41hd_19',
#  'gru42hd1_19',
#  'gru42hd2_19',
#  'gru43hd1_19',
#  'gru43hd2_19',
#  'gru43hd3_19',
#  'gru44hd_19',
#  'gru51hd_19',
#  'gru52hd1_19',
#  'gru53hd1_19',
#  'gru53hd2_19',
#  'gru53hd3_19',
#  'gru53hd4_19',
#  'gru54hd_19',
#  'gru61hd_19',
#  'gru62hd1_19',
#  'gru62hd2_19',
#  'gru63hd1_19',
#  'gru63hd2_19',
#  'gru63hd3_19',
#  'gru64hd_19',
#  'gru71hd_19',
#  'gru72hd1_19',
#  'gru72hd2_19',
#  'gru73hd1_19',
#  'gru73hd2_19',
#  'gru73hd3_19',
#  'gru74hd_19',
#  'gru81hd_19',
#  'gru82hd1_19',
#  'gru82hd2_19',
#  'gru83hd1_19',
#  'gru83hd2_19',
#  'gru83hd3_19',
#  'gru83hd4_19',
#  'gru84hd_19',
#  'gru84hd1_19',
#  'gru85hd1_19',
#  'gru86hd1_19',
#  'gru86hd2_19',
#  'gru87hd_19',
#  'ingotrhd_19',
#  'ingmo1hd_19',
#  'ingmo2hd_19',
#  'inghog1d_19',
#  'inghog2d_19',
#  'gashog1d_19',
#  'gashog21_19',
#  'gashog22_19',
#  'gashog23_19',
#  'gashog24_19',
#  'gashog26_19',
#  'gashog25_19',
#  'gashog2d_19',
#  'estrsocial_19',
#  'ld_19',
#  'linpe_19',
#  'linea_19',
#  'pobreza_19',
#  'factor07_19',
#  'year_20',
#  'mes_20',
#  'conglome_20',
#  'vivienda_20',
#  'hogar_20',
#  'ubigeo_20',
#  'dominio_20',
#  'mieperho_20',
#  'totmieho_20',
#  'percepho_20',
#  'ia01hd_20',
#  'ia02hd_20',
#  'ig03hd1_20',
#  'ig03hd2_20',
#  'ig03hd3_20',
#  'ig03hd4_20',
#  'ga03hd_20',
#  'ga04hd_20',
#  'sg23_20',
#  'sig24_20',
#  'sg25_20',
#  'sig26_20',
#  'sg42_20',
#  'sg421_20',
#  'sg422_20',
#  'sg423_20',
#  'sg42d_20',
#  'sg42d1_20',
#  'sg42d2_20',
#  'sg42d3_20',
#  'ingbruhd_20',
#  'ingnethd_20',
#  'pagesphd_20',
#  'ingindhd_20',
#  'ingauthd_20',
#  'insedthd_20',
#  'insedthd1_20',
#  'insedlhd_20',
#  'paesechd_20',
#  'paesechd1_20',
#  'ingseihd_20',
#  'isecauhd_20',
#  'ingexthd_20',
#  'ingtrahd_20',
#  'ingtrahd1_20',
#  'ingtexhd_20',
#  'ingrenhd_20',
#  'ingoexhd_20',
#  'g05hd_20',
#  'ig06hd_20',
#  'g05hd1_20',
#  'ig06hd1_20',
#  'g05hd2_20',
#  'ig06hd2_20',
#  'g05hd3_20',
#  'ig06hd3_20',
#  'g05hd4_20',
#  'ig06hd4_20',
#  'g05hd5_20',
#  'ig06hd5_20',
#  'g05hd6_20',
#  'ig06hd6_20',
#  'g07hd_20',
#  'ig08hd_20',
#  'ingtprhd_20',
#  'ingtpuhd1_20',
#  'ingtpuhd_20',
#  'ingtpu01_20',
#  'ingtpu02_20',
#  'ingtpu021_20',
#  'ingtpu03_20',
#  'ingtpu04_20',
#  'ingtpu05_20',
#  'ingtpu06_20',
#  'ingtpu061_20',
#  'ingtpu07_20',
#  'ingtpu071_20',
#  'ingtpu08_20',
#  'ingtpu081_20',
#  'ingtpu09_20',
#  'ingtpu091_20',
#  'gru11hd_20',
#  'gru12hd1_20',
#  'gru12hd2_20',
#  'gru13hd1_20',
#  'gru13hd2_20',
#  'gru13hd3_20',
#  'gru13hd4_20',
#  'gru14hd_20',
#  'gru14hd1_20',
#  'gru14hd2_20',
#  'gru14hd3_20',
#  'gru14hd4_20',
#  'gru14hd5_20',
#  'gru14hd6_20',
#  'gru21hd_20',
#  'gru22hd1_20',
#  'gru22hd2_20',
#  'gru23hd1_20',
#  'gru23hd2_20',
#  'gru23hd3_20',
#  'gru24hd_20',
#  'gru31hd_20',
#  'gru32hd1_20',
#  'gru32hd2_20',
#  'gru33hd1_20',
#  'gru33hd2_20',
#  'gru33hd3_20',
#  'gru34hd_20',
#  'gru41hd_20',
#  'gru42hd1_20',
#  'gru42hd2_20',
#  'gru43hd1_20',
#  'gru43hd2_20',
#  'gru43hd3_20',
#  'gru44hd_20',
#  'gru51hd_20',
#  'gru52hd1_20',
#  'gru53hd1_20',
#  'gru53hd2_20',
#  'gru53hd3_20',
#  'gru53hd4_20',
#  'gru54hd_20',
#  'gru61hd_20',
#  'gru62hd1_20',
#  'gru62hd2_20',
#  'gru63hd1_20',
#  'gru63hd2_20',
#  'gru63hd3_20',
#  'gru64hd_20',
#  'gru71hd_20',
#  'gru72hd1_20',
#  'gru72hd2_20',
#  'gru73hd1_20',
#  'gru73hd2_20',
#  'gru73hd3_20',
#  'gru74hd_20',
#  'gru81hd_20',
#  'gru82hd1_20',
#  'gru82hd2_20',
#  'gru83hd1_20',
#  'gru83hd2_20',
#  'gru83hd3_20',
#  'gru83hd4_20',
#  'gru84hd_20',
#  'gru84hd1_20',
#  'gru85hd1_20',
#  'gru86hd1_20',
#  'gru86hd2_20',
#  'gru87hd_20',
#  'ingotrhd_20',
#  'ingmo1hd_20',
#  'ingmo2hd_20',
#  'inghog1d_20',
#  'inghog1d1_20',
#  'inghog2d_20',
#  'inghog2d1_20',
#  'gashog1d_20',
#  'gashog21_20',
#  'gashog22_20',
#  'gashog23_20',
#  'gashog24_20',
#  'gashog26_20',
#  'gashog25_20',
#  'gashog2d_20',
#  'estrsocial_20',
#  'ld_20',
#  'linpe_20',
#  'linea_20',
#  'pobreza_20',
#  'tipocuestionario_20',
#  'tipoentrevista_20',
#  'factor07_20',
#  'nconglome_20',
#  'sub_conglome_20',
#  'lineav_rpl_20',
#  'lineav_20',
#  'pobrezav_20']

# %% [markdown]
# ## 1.0 Substract letters an d number, but not special characters

# %%
filter_list = []

for i in range(0,len(list(panel.columns))):

        w =  re.sub('[^-A-Za-z0-9]','', list(panel.columns)[i])
        filter_list.append(w)

# %%
filter_list
# Out:
# ['cong',
#  'viv',
#  'year16',
#  'mes16',
#  'nconglome16',
#  'conglome16',
#  'vivienda16',
#  'hog',
#  'ubigeo16',
#  'dominio16',
#  'percepho16',
#  'gru52hd216',
#  'ingpeihd16',
#  'mieperho16',
#  'totmieho16',
#  'ia01hd16',
#  'ia02hd16',
#  'ingbruhd16',
#  'ingnethd16',
#  'pagesphd16',
#  'ingindhd16',
#  'ingauthd16',
#  'insedthd16',
#  'insedlhd16',
#  'paesechd16',
#  'ingseihd16',
#  'isecauhd16',
#  'ingexthd16',
#  'ingtrahd16',
#  'ingtexhd16',
#  'ingrenhd16',
#  'ingoexhd16',
#  'g05hd16',
#  'ig06hd16',
#  'g05hd116',
#  'ig06hd116',
#  'g05hd216',
#  'ig06hd216',
#  'g05hd316',
#  'ig06hd316',
#  'g05hd416',
#  'ig06hd416',
#  'g05hd516',
#  'ig06hd516',
#  'g05hd616',
#  'ig06hd616',
#  'g07hd16',
#  'ig08hd16',
#  'ig03hd116',
#  'ig03hd216',
#  'ig03hd316',
#  'ig03hd416',
#  'sg2316',
#  'sig2416',
#  'sg2516',
#  'sig2616',
#  'ga03hd16',
#  'ga04hd16',
#  'sg4216',
#  'sg42d16',
#  'sg42116',
#  'sg42d116',
#  'sg42216',
#  'sg42d216',
#  'sg42316',
#  'sg42d316',
#  'ingtprhd16',
#  'ingtpuhd16',
#  'ingtpu0116',
#  'ingtpu0216',
#  'ingtpu0316',
#  'ingtpu0416',
#  'ingtpu0516',
#  'gru11hd16',
#  'gru12hd116',
#  'gru12hd216',
#  'gru13hd116',
#  'gru13hd216',
#  'gru13hd316',
#  'gru13hd416',
#  'gru14hd16',
#  'gru14hd116',
#  'gru14hd216',
#  'gru14hd316',
#  'gru14hd416',
#  'gru14hd516',
#  'gru14hd616',
#  'gru21hd16',
#  'gru22hd116',
#  'gru22hd216',
#  'gru23hd116',
#  'gru23hd216',
#  'gru23hd316',
#  'gru24hd16',
#  'gru31hd16',
#  'gru32hd116',
#  'gru32hd216',
#  'gru33hd116',
#  'gru33hd216',
#  'gru33hd316',
#  'gru34hd16',
#  'gru41hd16',
#  'gru42hd116',
#  'gru42hd216',
#  'gru43hd116',
#  'gru43hd216',
#  'gru43hd316',
#  'gru44hd16',
#  'gru51hd16',
#  'gru52hd116',
#  'gru53hd116',
#  'gru53hd216',
#  'gru53hd316',
#  'gru53hd416',
#  'gru54hd16',
#  'gru61hd16',
#  'gru62hd116',
#  'gru62hd216',
#  'gru63hd116',
#  'gru63hd216',
#  'gru63hd316',
#  'gru64hd16',
#  'gru71hd16',
#  'gru72hd116',
#  'gru72hd216',
#  'gru73hd116',
#  'gru73hd216',
#  'gru73hd316',
#  'gru74hd16',
#  'gru81hd16',
#  'gru82hd116',
#  'gru82hd216',
#  'gru83hd116',
#  'gru83hd216',
#  'gru83hd316',
#  'gru83hd416',
#  'gru84hd16',
#  'gru84hd116',
#  'gru85hd116',
#  'gru86hd116',
#  'gru86hd216',
#  'gru87hd16',
#  'ingotrhd16',
#  'ingmo1hd16',
#  'ingmo2hd16',
#  'inghog1d16',
#  'inghog2d16',
#  'gashog1d16',
#  'gashog2d16',
#  'linpe16',
#  'linea16',
#  'pobreza16',
#  'ld16',
#  'factor0716',
#  'estrsocial16',
#  'year17',
#  'mes17',
#  'nconglome17',
#  'conglome17',
#  'vivienda17',
#  'hogar17',
#  'ubigeo17',
#  'dominio17',
#  'percepho17',
#  'mieperho17',
#  'totmieho17',
#  'ia01hd17',
#  'ia02hd17',
#  'ingbruhd17',
#  'ingnethd17',
#  'pagesphd17',
#  'ingindhd17',
#  'ingauthd17',
#  'insedthd17',
#  'insedlhd17',
#  'paesechd17',
#  'ingseihd17',
#  'isecauhd17',
#  'ingexthd17',
#  'ingtrahd17',
#  'ingtexhd17',
#  'ingrenhd17',
#  'ingoexhd17',
#  'g05hd17',
#  'ig06hd17',
#  'g05hd117',
#  'ig06hd117',
#  'g05hd217',
#  'ig06hd217',
#  'g05hd317',
#  'ig06hd317',
#  'g05hd417',
#  'ig06hd417',
#  'g05hd517',
#  'ig06hd517',
#  'g05hd617',
#  'ig06hd617',
#  'g07hd17',
#  'ig08hd17',
#  'ig03hd117',
#  'ig03hd217',
#  'ig03hd317',
#  'ig03hd417',
#  'sg2317',
#  'sig2417',
#  'sg2517',
#  'sig2617',
#  'ga03hd17',
#  'ga04hd17',
#  'sg4217',
#  'sg42d17',
#  'sg42117',
#  'sg42d117',
#  'sg42217',
#  'sg42d217',
#  'sg42317',
#  'sg42d317',
#  'ingtprhd17',
#  'ingtpuhd17',
#  'ingtpu0117',
#  'ingtpu0217',
#  'ingtpu0317',
#  'ingtpu0417',
#  'ingtpu0517',
#  'gru11hd17',
#  'gru12hd117',
#  'gru12hd217',
#  'gru13hd117',
#  'gru13hd217',
#  'gru13hd317',
#  'gru13hd417',
#  'gru14hd17',
#  'gru14hd117',
#  'gru14hd217',
#  'gru14hd317',
#  'gru14hd417',
#  'gru14hd517',
#  'gru14hd617',
#  'gru21hd17',
#  'gru22hd117',
#  'gru22hd217',
#  'gru23hd117',
#  'gru23hd217',
#  'gru23hd317',
#  'gru24hd17',
#  'gru31hd17',
#  'gru32hd117',
#  'gru32hd217',
#  'gru33hd117',
#  'gru33hd217',
#  'gru33hd317',
#  'gru34hd17',
#  'gru41hd17',
#  'gru42hd117',
#  'gru42hd217',
#  'gru43hd117',
#  'gru43hd217',
#  'gru43hd317',
#  'gru44hd17',
#  'gru51hd17',
#  'gru52hd117',
#  'gru53hd117',
#  'gru53hd217',
#  'gru53hd317',
#  'gru53hd417',
#  'gru54hd17',
#  'gru61hd17',
#  'gru62hd117',
#  'gru62hd217',
#  'gru63hd117',
#  'gru63hd217',
#  'gru63hd317',
#  'gru64hd17',
#  'gru71hd17',
#  'gru72hd117',
#  'gru72hd217',
#  'gru73hd117',
#  'gru73hd217',
#  'gru73hd317',
#  'gru74hd17',
#  'gru81hd17',
#  'gru82hd117',
#  'gru82hd217',
#  'gru83hd117',
#  'gru83hd217',
#  'gru83hd317',
#  'gru83hd417',
#  'gru84hd17',
#  'gru84hd117',
#  'gru85hd117',
#  'gru86hd117',
#  'gru86hd217',
#  'gru87hd17',
#  'ingotrhd17',
#  'ingmo1hd17',
#  'ingmo2hd17',
#  'inghog1d17',
#  'inghog2d17',
#  'gashog1d17',
#  'gashog2117',
#  'gashog2217',
#  'gashog2317',
#  'gashog2417',
#  'gashog2617',
#  'gashog2517',
#  'gashog2d17',
#  'ld17',
#  'linpe17',
#  'linea17',
#  'pobreza17',
#  'estrsocial17',
#  'factor0717',
#  'year18',
#  'mes18',
#  'nconglome18',
#  'conglome18',
#  'vivienda18',
#  'hogar18',
#  'ubigeo18',
#  'dominio18',
#  'percepho18',
#  'mieperho18',
#  'totmieho18',
#  'ia01hd18',
#  'ia02hd18',
#  'ig03hd118',
#  'ig03hd218',
#  'ig03hd318',
#  'ig03hd418',
#  'ga03hd18',
#  'ga04hd18',
#  'sg2318',
#  'sig2418',
#  'sg2518',
#  'sig2618',
#  'sg4218',
#  'sg42118',
#  'sg42218',
#  'sg42318',
#  'sg42d18',
#  'sg42d118',
#  'sg42d218',
#  'sg42d318',
#  'ingbruhd18',
#  'ingnethd18',
#  'pagesphd18',
#  'ingindhd18',
#  'ingauthd18',
#  'insedthd18',
#  'insedlhd18',
#  'paesechd18',
#  'ingseihd18',
#  'isecauhd18',
#  'ingexthd18',
#  'ingtrahd18',
#  'ingtexhd18',
#  'ingrenhd18',
#  'ingoexhd18',
#  'g05hd18',
#  'ig06hd18',
#  'g05hd118',
#  'ig06hd118',
#  'g05hd218',
#  'ig06hd218',
#  'g05hd318',
#  'ig06hd318',
#  'g05hd418',
#  'ig06hd418',
#  'g05hd518',
#  'ig06hd518',
#  'g05hd618',
#  'ig06hd618',
#  'g07hd18',
#  'ig08hd18',
#  'ingtprhd18',
#  'ingtpuhd18',
#  'ingtpu0118',
#  'ingtpu0218',
#  'ingtpu0318',
#  'ingtpu0418',
#  'ingtpu0518',
#  'gru11hd18',
#  'gru12hd118',
#  'gru12hd218',
#  'gru13hd118',
#  'gru13hd218',
#  'gru13hd318',
#  'gru13hd418',
#  'gru14hd18',
#  'gru14hd118',
#  'gru14hd218',
#  'gru14hd318',
#  'gru14hd418',
#  'gru14hd518',
#  'gru14hd618',
#  'gru21hd18',
#  'gru22hd118',
#  'gru22hd218',
#  'gru23hd118',
#  'gru23hd218',
#  'gru23hd318',
#  'gru24hd18',
#  'gru31hd18',
#  'gru32hd118',
#  'gru32hd218',
#  'gru33hd118',
#  'gru33hd218',
#  'gru33hd318',
#  'gru34hd18',
#  'gru41hd18',
#  'gru42hd118',
#  'gru42hd218',
#  'gru43hd118',
#  'gru43hd218',
#  'gru43hd318',
#  'gru44hd18',
#  'gru51hd18',
#  'gru52hd118',
#  'gru53hd118',
#  'gru53hd218',
#  'gru53hd318',
#  'gru53hd418',
#  'gru54hd18',
#  'gru61hd18',
#  'gru62hd118',
#  'gru62hd218',
#  'gru63hd118',
#  'gru63hd218',
#  'gru63hd318',
#  'gru64hd18',
#  'gru71hd18',
#  'gru72hd118',
#  'gru72hd218',
#  'gru73hd118',
#  'gru73hd218',
#  'gru73hd318',
#  'gru74hd18',
#  'gru81hd18',
#  'gru82hd118',
#  'gru82hd218',
#  'gru83hd118',
#  'gru83hd218',
#  'gru83hd318',
#  'gru83hd418',
#  'gru84hd18',
#  'gru84hd118',
#  'gru85hd118',
#  'gru86hd118',
#  'gru86hd218',
#  'gru87hd18',
#  'ingotrhd18',
#  'ingmo1hd18',
#  'ingmo2hd18',
#  'inghog1d18',
#  'inghog2d18',
#  'gashog1d18',
#  'gashog2118',
#  'gashog2218',
#  'gashog2318',
#  'gashog2418',
#  'gashog2618',
#  'gashog2518',
#  'gashog2d18',
#  'ld18',
#  'estrsocial18',
#  'linpe18',
#  'linea18',
#  'pobreza18',
#  'factor0718',
#  'year19',
#  'mes19',
#  'nconglome19',
#  'conglome19',
#  'vivienda19',
#  'hogar19',
#  'ubigeo19',
#  'dominio19',
#  'percepho19',
#  'mieperho19',
#  'totmieho19',
#  'ia01hd19',
#  'ia02hd19',
#  'ig03hd119',
#  'ig03hd219',
#  'ig03hd319',
#  'ig03hd419',
#  'ga03hd19',
#  'ga04hd19',
#  'sg2319',
#  'sig2419',
#  'sg2519',
#  'sig2619',
#  'sg4219',
#  'sg42119',
#  'sg42219',
#  'sg42319',
#  'sg42d19',
#  'sg42d119',
#  'sg42d219',
#  'sg42d319',
#  'ingbruhd19',
#  'ingnethd19',
#  'pagesphd19',
#  'ingindhd19',
#  'ingauthd19',
#  'insedthd19',
#  'insedlhd19',
#  'paesechd19',
#  'ingseihd19',
#  'isecauhd19',
#  'ingexthd19',
#  'ingtrahd19',
#  'ingtexhd19',
#  'ingrenhd19',
#  'ingoexhd19',
#  'g05hd19',
#  'ig06hd19',
#  'g05hd119',
#  'ig06hd119',
#  'g05hd219',
#  'ig06hd219',
#  'g05hd319',
#  'ig06hd319',
#  'g05hd419',
#  'ig06hd419',
#  'g05hd519',
#  'ig06hd519',
#  'g05hd619',
#  'ig06hd619',
#  'g07hd19',
#  'ig08hd19',
#  'ingtprhd19',
#  'ingtpuhd19',
#  'ingtpu0119',
#  'ingtpu0219',
#  'ingtpu0319',
#  'ingtpu0419',
#  'ingtpu0519',
#  'gru11hd19',
#  'gru12hd119',
#  'gru12hd219',
#  'gru13hd119',
#  'gru13hd219',
#  'gru13hd319',
#  'gru13hd419',
#  'gru14hd19',
#  'gru14hd119',
#  'gru14hd219',
#  'gru14hd319',
#  'gru14hd419',
#  'gru14hd519',
#  'gru14hd619',
#  'gru21hd19',
#  'gru22hd119',
#  'gru22hd219',
#  'gru23hd119',
#  'gru23hd219',
#  'gru23hd319',
#  'gru24hd19',
#  'gru31hd19',
#  'gru32hd119',
#  'gru32hd219',
#  'gru33hd119',
#  'gru33hd219',
#  'gru33hd319',
#  'gru34hd19',
#  'gru41hd19',
#  'gru42hd119',
#  'gru42hd219',
#  'gru43hd119',
#  'gru43hd219',
#  'gru43hd319',
#  'gru44hd19',
#  'gru51hd19',
#  'gru52hd119',
#  'gru53hd119',
#  'gru53hd219',
#  'gru53hd319',
#  'gru53hd419',
#  'gru54hd19',
#  'gru61hd19',
#  'gru62hd119',
#  'gru62hd219',
#  'gru63hd119',
#  'gru63hd219',
#  'gru63hd319',
#  'gru64hd19',
#  'gru71hd19',
#  'gru72hd119',
#  'gru72hd219',
#  'gru73hd119',
#  'gru73hd219',
#  'gru73hd319',
#  'gru74hd19',
#  'gru81hd19',
#  'gru82hd119',
#  'gru82hd219',
#  'gru83hd119',
#  'gru83hd219',
#  'gru83hd319',
#  'gru83hd419',
#  'gru84hd19',
#  'gru84hd119',
#  'gru85hd119',
#  'gru86hd119',
#  'gru86hd219',
#  'gru87hd19',
#  'ingotrhd19',
#  'ingmo1hd19',
#  'ingmo2hd19',
#  'inghog1d19',
#  'inghog2d19',
#  'gashog1d19',
#  'gashog2119',
#  'gashog2219',
#  'gashog2319',
#  'gashog2419',
#  'gashog2619',
#  'gashog2519',
#  'gashog2d19',
#  'estrsocial19',
#  'ld19',
#  'linpe19',
#  'linea19',
#  'pobreza19',
#  'factor0719',
#  'year20',
#  'mes20',
#  'conglome20',
#  'vivienda20',
#  'hogar20',
#  'ubigeo20',
#  'dominio20',
#  'mieperho20',
#  'totmieho20',
#  'percepho20',
#  'ia01hd20',
#  'ia02hd20',
#  'ig03hd120',
#  'ig03hd220',
#  'ig03hd320',
#  'ig03hd420',
#  'ga03hd20',
#  'ga04hd20',
#  'sg2320',
#  'sig2420',
#  'sg2520',
#  'sig2620',
#  'sg4220',
#  'sg42120',
#  'sg42220',
#  'sg42320',
#  'sg42d20',
#  'sg42d120',
#  'sg42d220',
#  'sg42d320',
#  'ingbruhd20',
#  'ingnethd20',
#  'pagesphd20',
#  'ingindhd20',
#  'ingauthd20',
#  'insedthd20',
#  'insedthd120',
#  'insedlhd20',
#  'paesechd20',
#  'paesechd120',
#  'ingseihd20',
#  'isecauhd20',
#  'ingexthd20',
#  'ingtrahd20',
#  'ingtrahd120',
#  'ingtexhd20',
#  'ingrenhd20',
#  'ingoexhd20',
#  'g05hd20',
#  'ig06hd20',
#  'g05hd120',
#  'ig06hd120',
#  'g05hd220',
#  'ig06hd220',
#  'g05hd320',
#  'ig06hd320',
#  'g05hd420',
#  'ig06hd420',
#  'g05hd520',
#  'ig06hd520',
#  'g05hd620',
#  'ig06hd620',
#  'g07hd20',
#  'ig08hd20',
#  'ingtprhd20',
#  'ingtpuhd120',
#  'ingtpuhd20',
#  'ingtpu0120',
#  'ingtpu0220',
#  'ingtpu02120',
#  'ingtpu0320',
#  'ingtpu0420',
#  'ingtpu0520',
#  'ingtpu0620',
#  'ingtpu06120',
#  'ingtpu0720',
#  'ingtpu07120',
#  'ingtpu0820',
#  'ingtpu08120',
#  'ingtpu0920',
#  'ingtpu09120',
#  'gru11hd20',
#  'gru12hd120',
#  'gru12hd220',
#  'gru13hd120',
#  'gru13hd220',
#  'gru13hd320',
#  'gru13hd420',
#  'gru14hd20',
#  'gru14hd120',
#  'gru14hd220',
#  'gru14hd320',
#  'gru14hd420',
#  'gru14hd520',
#  'gru14hd620',
#  'gru21hd20',
#  'gru22hd120',
#  'gru22hd220',
#  'gru23hd120',
#  'gru23hd220',
#  'gru23hd320',
#  'gru24hd20',
#  'gru31hd20',
#  'gru32hd120',
#  'gru32hd220',
#  'gru33hd120',
#  'gru33hd220',
#  'gru33hd320',
#  'gru34hd20',
#  'gru41hd20',
#  'gru42hd120',
#  'gru42hd220',
#  'gru43hd120',
#  'gru43hd220',
#  'gru43hd320',
#  'gru44hd20',
#  'gru51hd20',
#  'gru52hd120',
#  'gru53hd120',
#  'gru53hd220',
#  'gru53hd320',
#  'gru53hd420',
#  'gru54hd20',
#  'gru61hd20',
#  'gru62hd120',
#  'gru62hd220',
#  'gru63hd120',
#  'gru63hd220',
#  'gru63hd320',
#  'gru64hd20',
#  'gru71hd20',
#  'gru72hd120',
#  'gru72hd220',
#  'gru73hd120',
#  'gru73hd220',
#  'gru73hd320',
#  'gru74hd20',
#  'gru81hd20',
#  'gru82hd120',
#  'gru82hd220',
#  'gru83hd120',
#  'gru83hd220',
#  'gru83hd320',
#  'gru83hd420',
#  'gru84hd20',
#  'gru84hd120',
#  'gru85hd120',
#  'gru86hd120',
#  'gru86hd220',
#  'gru87hd20',
#  'ingotrhd20',
#  'ingmo1hd20',
#  'ingmo2hd20',
#  'inghog1d20',
#  'inghog1d120',
#  'inghog2d20',
#  'inghog2d120',
#  'gashog1d20',
#  'gashog2120',
#  'gashog2220',
#  'gashog2320',
#  'gashog2420',
#  'gashog2620',
#  'gashog2520',
#  'gashog2d20',
#  'estrsocial20',
#  'ld20',
#  'linpe20',
#  'linea20',
#  'pobreza20',
#  'tipocuestionario20',
#  'tipoentrevista20',
#  'factor0720',
#  'nconglome20',
#  'subconglome20',
#  'lineavrpl20',
#  'lineav20',
#  'pobrezav20']

# %% [markdown]
# ## Drop special character '_'

# %%
filter_list = []

for i in range(0,len(list(panel.columns))):

        w =  re.sub('[\_]','', list(panel.columns)[i])
        filter_list.append(w)

filter_list
# Out:
# ['cong',
#  'viv',
#  'year16',
#  'mes16',
#  'nconglome16',
#  'conglome16',
#  'vivienda16',
#  'hog',
#  'ubigeo16',
#  'dominio16',
#  'percepho16',
#  'gru52hd216',
#  'ingpeihd16',
#  'mieperho16',
#  'totmieho16',
#  'ia01hd16',
#  'ia02hd16',
#  'ingbruhd16',
#  'ingnethd16',
#  'pagesphd16',
#  'ingindhd16',
#  'ingauthd16',
#  'insedthd16',
#  'insedlhd16',
#  'paesechd16',
#  'ingseihd16',
#  'isecauhd16',
#  'ingexthd16',
#  'ingtrahd16',
#  'ingtexhd16',
#  'ingrenhd16',
#  'ingoexhd16',
#  'g05hd16',
#  'ig06hd16',
#  'g05hd116',
#  'ig06hd116',
#  'g05hd216',
#  'ig06hd216',
#  'g05hd316',
#  'ig06hd316',
#  'g05hd416',
#  'ig06hd416',
#  'g05hd516',
#  'ig06hd516',
#  'g05hd616',
#  'ig06hd616',
#  'g07hd16',
#  'ig08hd16',
#  'ig03hd116',
#  'ig03hd216',
#  'ig03hd316',
#  'ig03hd416',
#  'sg2316',
#  'sig2416',
#  'sg2516',
#  'sig2616',
#  'ga03hd16',
#  'ga04hd16',
#  'sg4216',
#  'sg42d16',
#  'sg42116',
#  'sg42d116',
#  'sg42216',
#  'sg42d216',
#  'sg42316',
#  'sg42d316',
#  'ingtprhd16',
#  'ingtpuhd16',
#  'ingtpu0116',
#  'ingtpu0216',
#  'ingtpu0316',
#  'ingtpu0416',
#  'ingtpu0516',
#  'gru11hd16',
#  'gru12hd116',
#  'gru12hd216',
#  'gru13hd116',
#  'gru13hd216',
#  'gru13hd316',
#  'gru13hd416',
#  'gru14hd16',
#  'gru14hd116',
#  'gru14hd216',
#  'gru14hd316',
#  'gru14hd416',
#  'gru14hd516',
#  'gru14hd616',
#  'gru21hd16',
#  'gru22hd116',
#  'gru22hd216',
#  'gru23hd116',
#  'gru23hd216',
#  'gru23hd316',
#  'gru24hd16',
#  'gru31hd16',
#  'gru32hd116',
#  'gru32hd216',
#  'gru33hd116',
#  'gru33hd216',
#  'gru33hd316',
#  'gru34hd16',
#  'gru41hd16',
#  'gru42hd116',
#  'gru42hd216',
#  'gru43hd116',
#  'gru43hd216',
#  'gru43hd316',
#  'gru44hd16',
#  'gru51hd16',
#  'gru52hd116',
#  'gru53hd116',
#  'gru53hd216',
#  'gru53hd316',
#  'gru53hd416',
#  'gru54hd16',
#  'gru61hd16',
#  'gru62hd116',
#  'gru62hd216',
#  'gru63hd116',
#  'gru63hd216',
#  'gru63hd316',
#  'gru64hd16',
#  'gru71hd16',
#  'gru72hd116',
#  'gru72hd216',
#  'gru73hd116',
#  'gru73hd216',
#  'gru73hd316',
#  'gru74hd16',
#  'gru81hd16',
#  'gru82hd116',
#  'gru82hd216',
#  'gru83hd116',
#  'gru83hd216',
#  'gru83hd316',
#  'gru83hd416',
#  'gru84hd16',
#  'gru84hd116',
#  'gru85hd116',
#  'gru86hd116',
#  'gru86hd216',
#  'gru87hd16',
#  'ingotrhd16',
#  'ingmo1hd16',
#  'ingmo2hd16',
#  'inghog1d16',
#  'inghog2d16',
#  'gashog1d16',
#  'gashog2d16',
#  'linpe16',
#  'linea16',
#  'pobreza16',
#  'ld16',
#  'factor0716',
#  'estrsocial16',
#  'year17',
#  'mes17',
#  'nconglome17',
#  'conglome17',
#  'vivienda17',
#  'hogar17',
#  'ubigeo17',
#  'dominio17',
#  'percepho17',
#  'mieperho17',
#  'totmieho17',
#  'ia01hd17',
#  'ia02hd17',
#  'ingbruhd17',
#  'ingnethd17',
#  'pagesphd17',
#  'ingindhd17',
#  'ingauthd17',
#  'insedthd17',
#  'insedlhd17',
#  'paesechd17',
#  'ingseihd17',
#  'isecauhd17',
#  'ingexthd17',
#  'ingtrahd17',
#  'ingtexhd17',
#  'ingrenhd17',
#  'ingoexhd17',
#  'g05hd17',
#  'ig06hd17',
#  'g05hd117',
#  'ig06hd117',
#  'g05hd217',
#  'ig06hd217',
#  'g05hd317',
#  'ig06hd317',
#  'g05hd417',
#  'ig06hd417',
#  'g05hd517',
#  'ig06hd517',
#  'g05hd617',
#  'ig06hd617',
#  'g07hd17',
#  'ig08hd17',
#  'ig03hd117',
#  'ig03hd217',
#  'ig03hd317',
#  'ig03hd417',
#  'sg2317',
#  'sig2417',
#  'sg2517',
#  'sig2617',
#  'ga03hd17',
#  'ga04hd17',
#  'sg4217',
#  'sg42d17',
#  'sg42117',
#  'sg42d117',
#  'sg42217',
#  'sg42d217',
#  'sg42317',
#  'sg42d317',
#  'ingtprhd17',
#  'ingtpuhd17',
#  'ingtpu0117',
#  'ingtpu0217',
#  'ingtpu0317',
#  'ingtpu0417',
#  'ingtpu0517',
#  'gru11hd17',
#  'gru12hd117',
#  'gru12hd217',
#  'gru13hd117',
#  'gru13hd217',
#  'gru13hd317',
#  'gru13hd417',
#  'gru14hd17',
#  'gru14hd117',
#  'gru14hd217',
#  'gru14hd317',
#  'gru14hd417',
#  'gru14hd517',
#  'gru14hd617',
#  'gru21hd17',
#  'gru22hd117',
#  'gru22hd217',
#  'gru23hd117',
#  'gru23hd217',
#  'gru23hd317',
#  'gru24hd17',
#  'gru31hd17',
#  'gru32hd117',
#  'gru32hd217',
#  'gru33hd117',
#  'gru33hd217',
#  'gru33hd317',
#  'gru34hd17',
#  'gru41hd17',
#  'gru42hd117',
#  'gru42hd217',
#  'gru43hd117',
#  'gru43hd217',
#  'gru43hd317',
#  'gru44hd17',
#  'gru51hd17',
#  'gru52hd117',
#  'gru53hd117',
#  'gru53hd217',
#  'gru53hd317',
#  'gru53hd417',
#  'gru54hd17',
#  'gru61hd17',
#  'gru62hd117',
#  'gru62hd217',
#  'gru63hd117',
#  'gru63hd217',
#  'gru63hd317',
#  'gru64hd17',
#  'gru71hd17',
#  'gru72hd117',
#  'gru72hd217',
#  'gru73hd117',
#  'gru73hd217',
#  'gru73hd317',
#  'gru74hd17',
#  'gru81hd17',
#  'gru82hd117',
#  'gru82hd217',
#  'gru83hd117',
#  'gru83hd217',
#  'gru83hd317',
#  'gru83hd417',
#  'gru84hd17',
#  'gru84hd117',
#  'gru85hd117',
#  'gru86hd117',
#  'gru86hd217',
#  'gru87hd17',
#  'ingotrhd17',
#  'ingmo1hd17',
#  'ingmo2hd17',
#  'inghog1d17',
#  'inghog2d17',
#  'gashog1d17',
#  'gashog2117',
#  'gashog2217',
#  'gashog2317',
#  'gashog2417',
#  'gashog2617',
#  'gashog2517',
#  'gashog2d17',
#  'ld17',
#  'linpe17',
#  'linea17',
#  'pobreza17',
#  'estrsocial17',
#  'factor0717',
#  'year18',
#  'mes18',
#  'nconglome18',
#  'conglome18',
#  'vivienda18',
#  'hogar18',
#  'ubigeo18',
#  'dominio18',
#  'percepho18',
#  'mieperho18',
#  'totmieho18',
#  'ia01hd18',
#  'ia02hd18',
#  'ig03hd118',
#  'ig03hd218',
#  'ig03hd318',
#  'ig03hd418',
#  'ga03hd18',
#  'ga04hd18',
#  'sg2318',
#  'sig2418',
#  'sg2518',
#  'sig2618',
#  'sg4218',
#  'sg42118',
#  'sg42218',
#  'sg42318',
#  'sg42d18',
#  'sg42d118',
#  'sg42d218',
#  'sg42d318',
#  'ingbruhd18',
#  'ingnethd18',
#  'pagesphd18',
#  'ingindhd18',
#  'ingauthd18',
#  'insedthd18',
#  'insedlhd18',
#  'paesechd18',
#  'ingseihd18',
#  'isecauhd18',
#  'ingexthd18',
#  'ingtrahd18',
#  'ingtexhd18',
#  'ingrenhd18',
#  'ingoexhd18',
#  'g05hd18',
#  'ig06hd18',
#  'g05hd118',
#  'ig06hd118',
#  'g05hd218',
#  'ig06hd218',
#  'g05hd318',
#  'ig06hd318',
#  'g05hd418',
#  'ig06hd418',
#  'g05hd518',
#  'ig06hd518',
#  'g05hd618',
#  'ig06hd618',
#  'g07hd18',
#  'ig08hd18',
#  'ingtprhd18',
#  'ingtpuhd18',
#  'ingtpu0118',
#  'ingtpu0218',
#  'ingtpu0318',
#  'ingtpu0418',
#  'ingtpu0518',
#  'gru11hd18',
#  'gru12hd118',
#  'gru12hd218',
#  'gru13hd118',
#  'gru13hd218',
#  'gru13hd318',
#  'gru13hd418',
#  'gru14hd18',
#  'gru14hd118',
#  'gru14hd218',
#  'gru14hd318',
#  'gru14hd418',
#  'gru14hd518',
#  'gru14hd618',
#  'gru21hd18',
#  'gru22hd118',
#  'gru22hd218',
#  'gru23hd118',
#  'gru23hd218',
#  'gru23hd318',
#  'gru24hd18',
#  'gru31hd18',
#  'gru32hd118',
#  'gru32hd218',
#  'gru33hd118',
#  'gru33hd218',
#  'gru33hd318',
#  'gru34hd18',
#  'gru41hd18',
#  'gru42hd118',
#  'gru42hd218',
#  'gru43hd118',
#  'gru43hd218',
#  'gru43hd318',
#  'gru44hd18',
#  'gru51hd18',
#  'gru52hd118',
#  'gru53hd118',
#  'gru53hd218',
#  'gru53hd318',
#  'gru53hd418',
#  'gru54hd18',
#  'gru61hd18',
#  'gru62hd118',
#  'gru62hd218',
#  'gru63hd118',
#  'gru63hd218',
#  'gru63hd318',
#  'gru64hd18',
#  'gru71hd18',
#  'gru72hd118',
#  'gru72hd218',
#  'gru73hd118',
#  'gru73hd218',
#  'gru73hd318',
#  'gru74hd18',
#  'gru81hd18',
#  'gru82hd118',
#  'gru82hd218',
#  'gru83hd118',
#  'gru83hd218',
#  'gru83hd318',
#  'gru83hd418',
#  'gru84hd18',
#  'gru84hd118',
#  'gru85hd118',
#  'gru86hd118',
#  'gru86hd218',
#  'gru87hd18',
#  'ingotrhd18',
#  'ingmo1hd18',
#  'ingmo2hd18',
#  'inghog1d18',
#  'inghog2d18',
#  'gashog1d18',
#  'gashog2118',
#  'gashog2218',
#  'gashog2318',
#  'gashog2418',
#  'gashog2618',
#  'gashog2518',
#  'gashog2d18',
#  'ld18',
#  'estrsocial18',
#  'linpe18',
#  'linea18',
#  'pobreza18',
#  'factor0718',
#  'year19',
#  'mes19',
#  'nconglome19',
#  'conglome19',
#  'vivienda19',
#  'hogar19',
#  'ubigeo19',
#  'dominio19',
#  'percepho19',
#  'mieperho19',
#  'totmieho19',
#  'ia01hd19',
#  'ia02hd19',
#  'ig03hd119',
#  'ig03hd219',
#  'ig03hd319',
#  'ig03hd419',
#  'ga03hd19',
#  'ga04hd19',
#  'sg2319',
#  'sig2419',
#  'sg2519',
#  'sig2619',
#  'sg4219',
#  'sg42119',
#  'sg42219',
#  'sg42319',
#  'sg42d19',
#  'sg42d119',
#  'sg42d219',
#  'sg42d319',
#  'ingbruhd19',
#  'ingnethd19',
#  'pagesphd19',
#  'ingindhd19',
#  'ingauthd19',
#  'insedthd19',
#  'insedlhd19',
#  'paesechd19',
#  'ingseihd19',
#  'isecauhd19',
#  'ingexthd19',
#  'ingtrahd19',
#  'ingtexhd19',
#  'ingrenhd19',
#  'ingoexhd19',
#  'g05hd19',
#  'ig06hd19',
#  'g05hd119',
#  'ig06hd119',
#  'g05hd219',
#  'ig06hd219',
#  'g05hd319',
#  'ig06hd319',
#  'g05hd419',
#  'ig06hd419',
#  'g05hd519',
#  'ig06hd519',
#  'g05hd619',
#  'ig06hd619',
#  'g07hd19',
#  'ig08hd19',
#  'ingtprhd19',
#  'ingtpuhd19',
#  'ingtpu0119',
#  'ingtpu0219',
#  'ingtpu0319',
#  'ingtpu0419',
#  'ingtpu0519',
#  'gru11hd19',
#  'gru12hd119',
#  'gru12hd219',
#  'gru13hd119',
#  'gru13hd219',
#  'gru13hd319',
#  'gru13hd419',
#  'gru14hd19',
#  'gru14hd119',
#  'gru14hd219',
#  'gru14hd319',
#  'gru14hd419',
#  'gru14hd519',
#  'gru14hd619',
#  'gru21hd19',
#  'gru22hd119',
#  'gru22hd219',
#  'gru23hd119',
#  'gru23hd219',
#  'gru23hd319',
#  'gru24hd19',
#  'gru31hd19',
#  'gru32hd119',
#  'gru32hd219',
#  'gru33hd119',
#  'gru33hd219',
#  'gru33hd319',
#  'gru34hd19',
#  'gru41hd19',
#  'gru42hd119',
#  'gru42hd219',
#  'gru43hd119',
#  'gru43hd219',
#  'gru43hd319',
#  'gru44hd19',
#  'gru51hd19',
#  'gru52hd119',
#  'gru53hd119',
#  'gru53hd219',
#  'gru53hd319',
#  'gru53hd419',
#  'gru54hd19',
#  'gru61hd19',
#  'gru62hd119',
#  'gru62hd219',
#  'gru63hd119',
#  'gru63hd219',
#  'gru63hd319',
#  'gru64hd19',
#  'gru71hd19',
#  'gru72hd119',
#  'gru72hd219',
#  'gru73hd119',
#  'gru73hd219',
#  'gru73hd319',
#  'gru74hd19',
#  'gru81hd19',
#  'gru82hd119',
#  'gru82hd219',
#  'gru83hd119',
#  'gru83hd219',
#  'gru83hd319',
#  'gru83hd419',
#  'gru84hd19',
#  'gru84hd119',
#  'gru85hd119',
#  'gru86hd119',
#  'gru86hd219',
#  'gru87hd19',
#  'ingotrhd19',
#  'ingmo1hd19',
#  'ingmo2hd19',
#  'inghog1d19',
#  'inghog2d19',
#  'gashog1d19',
#  'gashog2119',
#  'gashog2219',
#  'gashog2319',
#  'gashog2419',
#  'gashog2619',
#  'gashog2519',
#  'gashog2d19',
#  'estrsocial19',
#  'ld19',
#  'linpe19',
#  'linea19',
#  'pobreza19',
#  'factor0719',
#  'year20',
#  'mes20',
#  'conglome20',
#  'vivienda20',
#  'hogar20',
#  'ubigeo20',
#  'dominio20',
#  'mieperho20',
#  'totmieho20',
#  'percepho20',
#  'ia01hd20',
#  'ia02hd20',
#  'ig03hd120',
#  'ig03hd220',
#  'ig03hd320',
#  'ig03hd420',
#  'ga03hd20',
#  'ga04hd20',
#  'sg2320',
#  'sig2420',
#  'sg2520',
#  'sig2620',
#  'sg4220',
#  'sg42120',
#  'sg42220',
#  'sg42320',
#  'sg42d20',
#  'sg42d120',
#  'sg42d220',
#  'sg42d320',
#  'ingbruhd20',
#  'ingnethd20',
#  'pagesphd20',
#  'ingindhd20',
#  'ingauthd20',
#  'insedthd20',
#  'insedthd120',
#  'insedlhd20',
#  'paesechd20',
#  'paesechd120',
#  'ingseihd20',
#  'isecauhd20',
#  'ingexthd20',
#  'ingtrahd20',
#  'ingtrahd120',
#  'ingtexhd20',
#  'ingrenhd20',
#  'ingoexhd20',
#  'g05hd20',
#  'ig06hd20',
#  'g05hd120',
#  'ig06hd120',
#  'g05hd220',
#  'ig06hd220',
#  'g05hd320',
#  'ig06hd320',
#  'g05hd420',
#  'ig06hd420',
#  'g05hd520',
#  'ig06hd520',
#  'g05hd620',
#  'ig06hd620',
#  'g07hd20',
#  'ig08hd20',
#  'ingtprhd20',
#  'ingtpuhd120',
#  'ingtpuhd20',
#  'ingtpu0120',
#  'ingtpu0220',
#  'ingtpu02120',
#  'ingtpu0320',
#  'ingtpu0420',
#  'ingtpu0520',
#  'ingtpu0620',
#  'ingtpu06120',
#  'ingtpu0720',
#  'ingtpu07120',
#  'ingtpu0820',
#  'ingtpu08120',
#  'ingtpu0920',
#  'ingtpu09120',
#  'gru11hd20',
#  'gru12hd120',
#  'gru12hd220',
#  'gru13hd120',
#  'gru13hd220',
#  'gru13hd320',
#  'gru13hd420',
#  'gru14hd20',
#  'gru14hd120',
#  'gru14hd220',
#  'gru14hd320',
#  'gru14hd420',
#  'gru14hd520',
#  'gru14hd620',
#  'gru21hd20',
#  'gru22hd120',
#  'gru22hd220',
#  'gru23hd120',
#  'gru23hd220',
#  'gru23hd320',
#  'gru24hd20',
#  'gru31hd20',
#  'gru32hd120',
#  'gru32hd220',
#  'gru33hd120',
#  'gru33hd220',
#  'gru33hd320',
#  'gru34hd20',
#  'gru41hd20',
#  'gru42hd120',
#  'gru42hd220',
#  'gru43hd120',
#  'gru43hd220',
#  'gru43hd320',
#  'gru44hd20',
#  'gru51hd20',
#  'gru52hd120',
#  'gru53hd120',
#  'gru53hd220',
#  'gru53hd320',
#  'gru53hd420',
#  'gru54hd20',
#  'gru61hd20',
#  'gru62hd120',
#  'gru62hd220',
#  'gru63hd120',
#  'gru63hd220',
#  'gru63hd320',
#  'gru64hd20',
#  'gru71hd20',
#  'gru72hd120',
#  'gru72hd220',
#  'gru73hd120',
#  'gru73hd220',
#  'gru73hd320',
#  'gru74hd20',
#  'gru81hd20',
#  'gru82hd120',
#  'gru82hd220',
#  'gru83hd120',
#  'gru83hd220',
#  'gru83hd320',
#  'gru83hd420',
#  'gru84hd20',
#  'gru84hd120',
#  'gru85hd120',
#  'gru86hd120',
#  'gru86hd220',
#  'gru87hd20',
#  'ingotrhd20',
#  'ingmo1hd20',
#  'ingmo2hd20',
#  'inghog1d20',
#  'inghog1d120',
#  'inghog2d20',
#  'inghog2d120',
#  'gashog1d20',
#  'gashog2120',
#  'gashog2220',
#  'gashog2320',
#  'gashog2420',
#  'gashog2620',
#  'gashog2520',
#  'gashog2d20',
#  'estrsocial20',
#  'ld20',
#  'linpe20',
#  'linea20',
#  'pobreza20',
#  'tipocuestionario20',
#  'tipoentrevista20',
#  'factor0720',
#  'nconglome20',
#  'subconglome20',
#  'lineavrpl20',
#  'lineav20',
#  'pobrezav20']

# %% [markdown]
# ## 2.0 Substract just letters (capital or lower)

# %%
filter_list = []

for i in range(0,len(list(panel.columns))):

        w = re.sub('[^a-zA-Z]','', list(panel.columns)[i])
        filter_list.append(w)

# %%
filter_list
# Out:
# ['cong',
#  'viv',
#  'year',
#  'mes',
#  'nconglome',
#  'conglome',
#  'vivienda',
#  'hog',
#  'ubigeo',
#  'dominio',
#  'percepho',
#  'gruhd',
#  'ingpeihd',
#  'mieperho',
#  'totmieho',
#  'iahd',
#  'iahd',
#  'ingbruhd',
#  'ingnethd',
#  'pagesphd',
#  'ingindhd',
#  'ingauthd',
#  'insedthd',
#  'insedlhd',
#  'paesechd',
#  'ingseihd',
#  'isecauhd',
#  'ingexthd',
#  'ingtrahd',
#  'ingtexhd',
#  'ingrenhd',
#  'ingoexhd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ighd',
#  'ighd',
#  'ighd',
#  'ighd',
#  'sg',
#  'sig',
#  'sg',
#  'sig',
#  'gahd',
#  'gahd',
#  'sg',
#  'sgd',
#  'sg',
#  'sgd',
#  'sg',
#  'sgd',
#  'sg',
#  'sgd',
#  'ingtprhd',
#  'ingtpuhd',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'ingotrhd',
#  'ingmohd',
#  'ingmohd',
#  'inghogd',
#  'inghogd',
#  'gashogd',
#  'gashogd',
#  'linpe',
#  'linea',
#  'pobreza',
#  'ld',
#  'factor',
#  'estrsocial',
#  'year',
#  'mes',
#  'nconglome',
#  'conglome',
#  'vivienda',
#  'hogar',
#  'ubigeo',
#  'dominio',
#  'percepho',
#  'mieperho',
#  'totmieho',
#  'iahd',
#  'iahd',
#  'ingbruhd',
#  'ingnethd',
#  'pagesphd',
#  'ingindhd',
#  'ingauthd',
#  'insedthd',
#  'insedlhd',
#  'paesechd',
#  'ingseihd',
#  'isecauhd',
#  'ingexthd',
#  'ingtrahd',
#  'ingtexhd',
#  'ingrenhd',
#  'ingoexhd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ighd',
#  'ighd',
#  'ighd',
#  'ighd',
#  'sg',
#  'sig',
#  'sg',
#  'sig',
#  'gahd',
#  'gahd',
#  'sg',
#  'sgd',
#  'sg',
#  'sgd',
#  'sg',
#  'sgd',
#  'sg',
#  'sgd',
#  'ingtprhd',
#  'ingtpuhd',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'ingotrhd',
#  'ingmohd',
#  'ingmohd',
#  'inghogd',
#  'inghogd',
#  'gashogd',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashogd',
#  'ld',
#  'linpe',
#  'linea',
#  'pobreza',
#  'estrsocial',
#  'factor',
#  'year',
#  'mes',
#  'nconglome',
#  'conglome',
#  'vivienda',
#  'hogar',
#  'ubigeo',
#  'dominio',
#  'percepho',
#  'mieperho',
#  'totmieho',
#  'iahd',
#  'iahd',
#  'ighd',
#  'ighd',
#  'ighd',
#  'ighd',
#  'gahd',
#  'gahd',
#  'sg',
#  'sig',
#  'sg',
#  'sig',
#  'sg',
#  'sg',
#  'sg',
#  'sg',
#  'sgd',
#  'sgd',
#  'sgd',
#  'sgd',
#  'ingbruhd',
#  'ingnethd',
#  'pagesphd',
#  'ingindhd',
#  'ingauthd',
#  'insedthd',
#  'insedlhd',
#  'paesechd',
#  'ingseihd',
#  'isecauhd',
#  'ingexthd',
#  'ingtrahd',
#  'ingtexhd',
#  'ingrenhd',
#  'ingoexhd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ingtprhd',
#  'ingtpuhd',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'ingotrhd',
#  'ingmohd',
#  'ingmohd',
#  'inghogd',
#  'inghogd',
#  'gashogd',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashogd',
#  'ld',
#  'estrsocial',
#  'linpe',
#  'linea',
#  'pobreza',
#  'factor',
#  'year',
#  'mes',
#  'nconglome',
#  'conglome',
#  'vivienda',
#  'hogar',
#  'ubigeo',
#  'dominio',
#  'percepho',
#  'mieperho',
#  'totmieho',
#  'iahd',
#  'iahd',
#  'ighd',
#  'ighd',
#  'ighd',
#  'ighd',
#  'gahd',
#  'gahd',
#  'sg',
#  'sig',
#  'sg',
#  'sig',
#  'sg',
#  'sg',
#  'sg',
#  'sg',
#  'sgd',
#  'sgd',
#  'sgd',
#  'sgd',
#  'ingbruhd',
#  'ingnethd',
#  'pagesphd',
#  'ingindhd',
#  'ingauthd',
#  'insedthd',
#  'insedlhd',
#  'paesechd',
#  'ingseihd',
#  'isecauhd',
#  'ingexthd',
#  'ingtrahd',
#  'ingtexhd',
#  'ingrenhd',
#  'ingoexhd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ingtprhd',
#  'ingtpuhd',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'ingotrhd',
#  'ingmohd',
#  'ingmohd',
#  'inghogd',
#  'inghogd',
#  'gashogd',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashogd',
#  'estrsocial',
#  'ld',
#  'linpe',
#  'linea',
#  'pobreza',
#  'factor',
#  'year',
#  'mes',
#  'conglome',
#  'vivienda',
#  'hogar',
#  'ubigeo',
#  'dominio',
#  'mieperho',
#  'totmieho',
#  'percepho',
#  'iahd',
#  'iahd',
#  'ighd',
#  'ighd',
#  'ighd',
#  'ighd',
#  'gahd',
#  'gahd',
#  'sg',
#  'sig',
#  'sg',
#  'sig',
#  'sg',
#  'sg',
#  'sg',
#  'sg',
#  'sgd',
#  'sgd',
#  'sgd',
#  'sgd',
#  'ingbruhd',
#  'ingnethd',
#  'pagesphd',
#  'ingindhd',
#  'ingauthd',
#  'insedthd',
#  'insedthd',
#  'insedlhd',
#  'paesechd',
#  'paesechd',
#  'ingseihd',
#  'isecauhd',
#  'ingexthd',
#  'ingtrahd',
#  'ingtrahd',
#  'ingtexhd',
#  'ingrenhd',
#  'ingoexhd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ghd',
#  'ighd',
#  'ingtprhd',
#  'ingtpuhd',
#  'ingtpuhd',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'ingtpu',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'gruhd',
#  'ingotrhd',
#  'ingmohd',
#  'ingmohd',
#  'inghogd',
#  'inghogd',
#  'inghogd',
#  'inghogd',
#  'gashogd',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashog',
#  'gashogd',
#  'estrsocial',
#  'ld',
#  'linpe',
#  'linea',
#  'pobreza',
#  'tipocuestionario',
#  'tipoentrevista',
#  'factor',
#  'nconglome',
#  'subconglome',
#  'lineavrpl',
#  'lineav',
#  'pobrezav']

# %%
filter_list = []

for i in range(0,len(list(panel.columns))):

        w = re.sub('[^0-9]','', list(panel.columns)[i])
        filter_list.append(w)
        

        
filter_list
# Out:
# ['',
#  '',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '',
#  '16',
#  '16',
#  '16',
#  '52216',
#  '16',
#  '16',
#  '16',
#  '0116',
#  '0216',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '16',
#  '0516',
#  '0616',
#  '05116',
#  '06116',
#  '05216',
#  '06216',
#  '05316',
#  '06316',
#  '05416',
#  '06416',
#  '05516',
#  '06516',
#  '05616',
#  '06616',
#  '0716',
#  '0816',
#  '03116',
#  '03216',
#  '03316',
#  '03416',
#  '2316',
#  '2416',
#  '2516',
#  '2616',
#  '0316',
#  '0416',
#  '4216',
#  '4216',
#  '42116',
#  '42116',
#  '42216',
#  '42216',
#  '42316',
#  '42316',
#  '16',
#  '16',
#  '0116',
#  '0216',
#  '0316',
#  '0416',
#  '0516',
#  '1116',
#  '12116',
#  '12216',
#  '13116',
#  '13216',
#  '13316',
#  '13416',
#  '1416',
#  '14116',
#  '14216',
#  '14316',
#  '14416',
#  '14516',
#  '14616',
#  '2116',
#  '22116',
#  '22216',
#  '23116',
#  '23216',
#  '23316',
#  '2416',
#  '3116',
#  '32116',
#  '32216',
#  '33116',
#  '33216',
#  '33316',
#  '3416',
#  '4116',
#  '42116',
#  '42216',
#  '43116',
#  '43216',
#  '43316',
#  '4416',
#  '5116',
#  '52116',
#  '53116',
#  '53216',
#  '53316',
#  '53416',
#  '5416',
#  '6116',
#  '62116',
#  '62216',
#  '63116',
#  '63216',
#  '63316',
#  '6416',
#  '7116',
#  '72116',
#  '72216',
#  '73116',
#  '73216',
#  '73316',
#  '7416',
#  '8116',
#  '82116',
#  '82216',
#  '83116',
#  '83216',
#  '83316',
#  '83416',
#  '8416',
#  '84116',
#  '85116',
#  '86116',
#  '86216',
#  '8716',
#  '16',
#  '116',
#  '216',
#  '116',
#  '216',
#  '116',
#  '216',
#  '16',
#  '16',
#  '16',
#  '16',
#  '0716',
#  '16',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '0117',
#  '0217',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '0517',
#  '0617',
#  '05117',
#  '06117',
#  '05217',
#  '06217',
#  '05317',
#  '06317',
#  '05417',
#  '06417',
#  '05517',
#  '06517',
#  '05617',
#  '06617',
#  '0717',
#  '0817',
#  '03117',
#  '03217',
#  '03317',
#  '03417',
#  '2317',
#  '2417',
#  '2517',
#  '2617',
#  '0317',
#  '0417',
#  '4217',
#  '4217',
#  '42117',
#  '42117',
#  '42217',
#  '42217',
#  '42317',
#  '42317',
#  '17',
#  '17',
#  '0117',
#  '0217',
#  '0317',
#  '0417',
#  '0517',
#  '1117',
#  '12117',
#  '12217',
#  '13117',
#  '13217',
#  '13317',
#  '13417',
#  '1417',
#  '14117',
#  '14217',
#  '14317',
#  '14417',
#  '14517',
#  '14617',
#  '2117',
#  '22117',
#  '22217',
#  '23117',
#  '23217',
#  '23317',
#  '2417',
#  '3117',
#  '32117',
#  '32217',
#  '33117',
#  '33217',
#  '33317',
#  '3417',
#  '4117',
#  '42117',
#  '42217',
#  '43117',
#  '43217',
#  '43317',
#  '4417',
#  '5117',
#  '52117',
#  '53117',
#  '53217',
#  '53317',
#  '53417',
#  '5417',
#  '6117',
#  '62117',
#  '62217',
#  '63117',
#  '63217',
#  '63317',
#  '6417',
#  '7117',
#  '72117',
#  '72217',
#  '73117',
#  '73217',
#  '73317',
#  '7417',
#  '8117',
#  '82117',
#  '82217',
#  '83117',
#  '83217',
#  '83317',
#  '83417',
#  '8417',
#  '84117',
#  '85117',
#  '86117',
#  '86217',
#  '8717',
#  '17',
#  '117',
#  '217',
#  '117',
#  '217',
#  '117',
#  '2117',
#  '2217',
#  '2317',
#  '2417',
#  '2617',
#  '2517',
#  '217',
#  '17',
#  '17',
#  '17',
#  '17',
#  '17',
#  '0717',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '0118',
#  '0218',
#  '03118',
#  '03218',
#  '03318',
#  '03418',
#  '0318',
#  '0418',
#  '2318',
#  '2418',
#  '2518',
#  '2618',
#  '4218',
#  '42118',
#  '42218',
#  '42318',
#  '4218',
#  '42118',
#  '42218',
#  '42318',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '0518',
#  '0618',
#  '05118',
#  '06118',
#  '05218',
#  '06218',
#  '05318',
#  '06318',
#  '05418',
#  '06418',
#  '05518',
#  '06518',
#  '05618',
#  '06618',
#  '0718',
#  '0818',
#  '18',
#  '18',
#  '0118',
#  '0218',
#  '0318',
#  '0418',
#  '0518',
#  '1118',
#  '12118',
#  '12218',
#  '13118',
#  '13218',
#  '13318',
#  '13418',
#  '1418',
#  '14118',
#  '14218',
#  '14318',
#  '14418',
#  '14518',
#  '14618',
#  '2118',
#  '22118',
#  '22218',
#  '23118',
#  '23218',
#  '23318',
#  '2418',
#  '3118',
#  '32118',
#  '32218',
#  '33118',
#  '33218',
#  '33318',
#  '3418',
#  '4118',
#  '42118',
#  '42218',
#  '43118',
#  '43218',
#  '43318',
#  '4418',
#  '5118',
#  '52118',
#  '53118',
#  '53218',
#  '53318',
#  '53418',
#  '5418',
#  '6118',
#  '62118',
#  '62218',
#  '63118',
#  '63218',
#  '63318',
#  '6418',
#  '7118',
#  '72118',
#  '72218',
#  '73118',
#  '73218',
#  '73318',
#  '7418',
#  '8118',
#  '82118',
#  '82218',
#  '83118',
#  '83218',
#  '83318',
#  '83418',
#  '8418',
#  '84118',
#  '85118',
#  '86118',
#  '86218',
#  '8718',
#  '18',
#  '118',
#  '218',
#  '118',
#  '218',
#  '118',
#  '2118',
#  '2218',
#  '2318',
#  '2418',
#  '2618',
#  '2518',
#  '218',
#  '18',
#  '18',
#  '18',
#  '18',
#  '18',
#  '0718',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '0119',
#  '0219',
#  '03119',
#  '03219',
#  '03319',
#  '03419',
#  '0319',
#  '0419',
#  '2319',
#  '2419',
#  '2519',
#  '2619',
#  '4219',
#  '42119',
#  '42219',
#  '42319',
#  '4219',
#  '42119',
#  '42219',
#  '42319',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '0519',
#  '0619',
#  '05119',
#  '06119',
#  '05219',
#  '06219',
#  '05319',
#  '06319',
#  '05419',
#  '06419',
#  '05519',
#  '06519',
#  '05619',
#  '06619',
#  '0719',
#  '0819',
#  '19',
#  '19',
#  '0119',
#  '0219',
#  '0319',
#  '0419',
#  '0519',
#  '1119',
#  '12119',
#  '12219',
#  '13119',
#  '13219',
#  '13319',
#  '13419',
#  '1419',
#  '14119',
#  '14219',
#  '14319',
#  '14419',
#  '14519',
#  '14619',
#  '2119',
#  '22119',
#  '22219',
#  '23119',
#  '23219',
#  '23319',
#  '2419',
#  '3119',
#  '32119',
#  '32219',
#  '33119',
#  '33219',
#  '33319',
#  '3419',
#  '4119',
#  '42119',
#  '42219',
#  '43119',
#  '43219',
#  '43319',
#  '4419',
#  '5119',
#  '52119',
#  '53119',
#  '53219',
#  '53319',
#  '53419',
#  '5419',
#  '6119',
#  '62119',
#  '62219',
#  '63119',
#  '63219',
#  '63319',
#  '6419',
#  '7119',
#  '72119',
#  '72219',
#  '73119',
#  '73219',
#  '73319',
#  '7419',
#  '8119',
#  '82119',
#  '82219',
#  '83119',
#  '83219',
#  '83319',
#  '83419',
#  '8419',
#  '84119',
#  '85119',
#  '86119',
#  '86219',
#  '8719',
#  '19',
#  '119',
#  '219',
#  '119',
#  '219',
#  '119',
#  '2119',
#  '2219',
#  '2319',
#  '2419',
#  '2619',
#  '2519',
#  '219',
#  '19',
#  '19',
#  '19',
#  '19',
#  '19',
#  '0719',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '0120',
#  '0220',
#  '03120',
#  '03220',
#  '03320',
#  '03420',
#  '0320',
#  '0420',
#  '2320',
#  '2420',
#  '2520',
#  '2620',
#  '4220',
#  '42120',
#  '42220',
#  '42320',
#  '4220',
#  '42120',
#  '42220',
#  '42320',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '120',
#  '20',
#  '20',
#  '120',
#  '20',
#  '20',
#  '20',
#  '20',
#  '120',
#  '20',
#  '20',
#  '20',
#  '0520',
#  '0620',
#  '05120',
#  '06120',
#  '05220',
#  '06220',
#  '05320',
#  '06320',
#  '05420',
#  '06420',
#  '05520',
#  '06520',
#  '05620',
#  '06620',
#  '0720',
#  '0820',
#  '20',
#  '120',
#  '20',
#  '0120',
#  '0220',
#  '02120',
#  '0320',
#  '0420',
#  '0520',
#  '0620',
#  '06120',
#  '0720',
#  '07120',
#  '0820',
#  '08120',
#  '0920',
#  '09120',
#  '1120',
#  '12120',
#  '12220',
#  '13120',
#  '13220',
#  '13320',
#  '13420',
#  '1420',
#  '14120',
#  '14220',
#  '14320',
#  '14420',
#  '14520',
#  '14620',
#  '2120',
#  '22120',
#  '22220',
#  '23120',
#  '23220',
#  '23320',
#  '2420',
#  '3120',
#  '32120',
#  '32220',
#  '33120',
#  '33220',
#  '33320',
#  '3420',
#  '4120',
#  '42120',
#  '42220',
#  '43120',
#  '43220',
#  '43320',
#  '4420',
#  '5120',
#  '52120',
#  '53120',
#  '53220',
#  '53320',
#  '53420',
#  '5420',
#  '6120',
#  '62120',
#  '62220',
#  '63120',
#  '63220',
#  '63320',
#  '6420',
#  '7120',
#  '72120',
#  '72220',
#  '73120',
#  '73220',
#  '73320',
#  '7420',
#  '8120',
#  '82120',
#  '82220',
#  '83120',
#  '83220',
#  '83320',
#  '83420',
#  '8420',
#  '84120',
#  '85120',
#  '86120',
#  '86220',
#  '8720',
#  '20',
#  '120',
#  '220',
#  '120',
#  '1120',
#  '220',
#  '2120',
#  '120',
#  '2120',
#  '2220',
#  '2320',
#  '2420',
#  '2620',
#  '2520',
#  '220',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20',
#  '0720',
#  '20',
#  '20',
#  '20',
#  '20',
#  '20']

# %% [markdown]
# ## 3.0  Drop last three string

# %%
filter_list = []

for i in range(0,len(list(panel.columns))):

        w = re.sub(".{3}$",'', list(panel.columns)[i])
        filter_list.append(w)

# %%
len(filter_list)
# Out:
# 804

# %%
filter_list
# Out:
# ['c',
#  '',
#  'year',
#  'mes',
#  'nconglome',
#  'conglome',
#  'vivienda',
#  '',
#  'ubigeo',
#  'dominio',
#  'percepho',
#  'gru52hd2',
#  'ingpeihd',
#  'mieperho',
#  'totmieho',
#  'ia01hd',
#  'ia02hd',
#  'ingbruhd',
#  'ingnethd',
#  'pagesphd',
#  'ingindhd',
#  'ingauthd',
#  'insedthd',
#  'insedlhd',
#  'paesechd',
#  'ingseihd',
#  'isecauhd',
#  'ingexthd',
#  'ingtrahd',
#  'ingtexhd',
#  'ingrenhd',
#  'ingoexhd',
#  'g05hd',
#  'ig06hd',
#  'g05hd1',
#  'ig06hd1',
#  'g05hd2',
#  'ig06hd2',
#  'g05hd3',
#  'ig06hd3',
#  'g05hd4',
#  'ig06hd4',
#  'g05hd5',
#  'ig06hd5',
#  'g05hd6',
#  'ig06hd6',
#  'g07hd',
#  'ig08hd',
#  'ig03hd1',
#  'ig03hd2',
#  'ig03hd3',
#  'ig03hd4',
#  'sg23',
#  'sig24',
#  'sg25',
#  'sig26',
#  'ga03hd',
#  'ga04hd',
#  'sg42',
#  'sg42d',
#  'sg421',
#  'sg42d1',
#  'sg422',
#  'sg42d2',
#  'sg423',
#  'sg42d3',
#  'ingtprhd',
#  'ingtpuhd',
#  'ingtpu01',
#  'ingtpu02',
#  'ingtpu03',
#  'ingtpu04',
#  'ingtpu05',
#  'gru11hd',
#  'gru12hd1',
#  'gru12hd2',
#  'gru13hd1',
#  'gru13hd2',
#  'gru13hd3',
#  'gru13hd4',
#  'gru14hd',
#  'gru14hd1',
#  'gru14hd2',
#  'gru14hd3',
#  'gru14hd4',
#  'gru14hd5',
#  'gru14hd6',
#  'gru21hd',
#  'gru22hd1',
#  'gru22hd2',
#  'gru23hd1',
#  'gru23hd2',
#  'gru23hd3',
#  'gru24hd',
#  'gru31hd',
#  'gru32hd1',
#  'gru32hd2',
#  'gru33hd1',
#  'gru33hd2',
#  'gru33hd3',
#  'gru34hd',
#  'gru41hd',
#  'gru42hd1',
#  'gru42hd2',
#  'gru43hd1',
#  'gru43hd2',
#  'gru43hd3',
#  'gru44hd',
#  'gru51hd',
#  'gru52hd1',
#  'gru53hd1',
#  'gru53hd2',
#  'gru53hd3',
#  'gru53hd4',
#  'gru54hd',
#  'gru61hd',
#  'gru62hd1',
#  'gru62hd2',
#  'gru63hd1',
#  'gru63hd2',
#  'gru63hd3',
#  'gru64hd',
#  'gru71hd',
#  'gru72hd1',
#  'gru72hd2',
#  'gru73hd1',
#  'gru73hd2',
#  'gru73hd3',
#  'gru74hd',
#  'gru81hd',
#  'gru82hd1',
#  'gru82hd2',
#  'gru83hd1',
#  'gru83hd2',
#  'gru83hd3',
#  'gru83hd4',
#  'gru84hd',
#  'gru84hd1',
#  'gru85hd1',
#  'gru86hd1',
#  'gru86hd2',
#  'gru87hd',
#  'ingotrhd',
#  'ingmo1hd',
#  'ingmo2hd',
#  'inghog1d',
#  'inghog2d',
#  'gashog1d',
#  'gashog2d',
#  'linpe',
#  'linea',
#  'pobreza',
#  'ld',
#  'factor07',
#  'estrsocial',
#  'year',
#  'mes',
#  'nconglome',
#  'conglome',
#  'vivienda',
#  'hogar',
#  'ubigeo',
#  'dominio',
#  'percepho',
#  'mieperho',
#  'totmieho',
#  'ia01hd',
#  'ia02hd',
#  'ingbruhd',
#  'ingnethd',
#  'pagesphd',
#  'ingindhd',
#  'ingauthd',
#  'insedthd',
#  'insedlhd',
#  'paesechd',
#  'ingseihd',
#  'isecauhd',
#  'ingexthd',
#  'ingtrahd',
#  'ingtexhd',
#  'ingrenhd',
#  'ingoexhd',
#  'g05hd',
#  'ig06hd',
#  'g05hd1',
#  'ig06hd1',
#  'g05hd2',
#  'ig06hd2',
#  'g05hd3',
#  'ig06hd3',
#  'g05hd4',
#  'ig06hd4',
#  'g05hd5',
#  'ig06hd5',
#  'g05hd6',
#  'ig06hd6',
#  'g07hd',
#  'ig08hd',
#  'ig03hd1',
#  'ig03hd2',
#  'ig03hd3',
#  'ig03hd4',
#  'sg23',
#  'sig24',
#  'sg25',
#  'sig26',
#  'ga03hd',
#  'ga04hd',
#  'sg42',
#  'sg42d',
#  'sg421',
#  'sg42d1',
#  'sg422',
#  'sg42d2',
#  'sg423',
#  'sg42d3',
#  'ingtprhd',
#  'ingtpuhd',
#  'ingtpu01',
#  'ingtpu02',
#  'ingtpu03',
#  'ingtpu04',
#  'ingtpu05',
#  'gru11hd',
#  'gru12hd1',
#  'gru12hd2',
#  'gru13hd1',
#  'gru13hd2',
#  'gru13hd3',
#  'gru13hd4',
#  'gru14hd',
#  'gru14hd1',
#  'gru14hd2',
#  'gru14hd3',
#  'gru14hd4',
#  'gru14hd5',
#  'gru14hd6',
#  'gru21hd',
#  'gru22hd1',
#  'gru22hd2',
#  'gru23hd1',
#  'gru23hd2',
#  'gru23hd3',
#  'gru24hd',
#  'gru31hd',
#  'gru32hd1',
#  'gru32hd2',
#  'gru33hd1',
#  'gru33hd2',
#  'gru33hd3',
#  'gru34hd',
#  'gru41hd',
#  'gru42hd1',
#  'gru42hd2',
#  'gru43hd1',
#  'gru43hd2',
#  'gru43hd3',
#  'gru44hd',
#  'gru51hd',
#  'gru52hd1',
#  'gru53hd1',
#  'gru53hd2',
#  'gru53hd3',
#  'gru53hd4',
#  'gru54hd',
#  'gru61hd',
#  'gru62hd1',
#  'gru62hd2',
#  'gru63hd1',
#  'gru63hd2',
#  'gru63hd3',
#  'gru64hd',
#  'gru71hd',
#  'gru72hd1',
#  'gru72hd2',
#  'gru73hd1',
#  'gru73hd2',
#  'gru73hd3',
#  'gru74hd',
#  'gru81hd',
#  'gru82hd1',
#  'gru82hd2',
#  'gru83hd1',
#  'gru83hd2',
#  'gru83hd3',
#  'gru83hd4',
#  'gru84hd',
#  'gru84hd1',
#  'gru85hd1',
#  'gru86hd1',
#  'gru86hd2',
#  'gru87hd',
#  'ingotrhd',
#  'ingmo1hd',
#  'ingmo2hd',
#  'inghog1d',
#  'inghog2d',
#  'gashog1d',
#  'gashog21',
#  'gashog22',
#  'gashog23',
#  'gashog24',
#  'gashog26',
#  'gashog25',
#  'gashog2d',
#  'ld',
#  'linpe',
#  'linea',
#  'pobreza',
#  'estrsocial',
#  'factor07',
#  'year',
#  'mes',
#  'nconglome',
#  'conglome',
#  'vivienda',
#  'hogar',
#  'ubigeo',
#  'dominio',
#  'percepho',
#  'mieperho',
#  'totmieho',
#  'ia01hd',
#  'ia02hd',
#  'ig03hd1',
#  'ig03hd2',
#  'ig03hd3',
#  'ig03hd4',
#  'ga03hd',
#  'ga04hd',
#  'sg23',
#  'sig24',
#  'sg25',
#  'sig26',
#  'sg42',
#  'sg421',
#  'sg422',
#  'sg423',
#  'sg42d',
#  'sg42d1',
#  'sg42d2',
#  'sg42d3',
#  'ingbruhd',
#  'ingnethd',
#  'pagesphd',
#  'ingindhd',
#  'ingauthd',
#  'insedthd',
#  'insedlhd',
#  'paesechd',
#  'ingseihd',
#  'isecauhd',
#  'ingexthd',
#  'ingtrahd',
#  'ingtexhd',
#  'ingrenhd',
#  'ingoexhd',
#  'g05hd',
#  'ig06hd',
#  'g05hd1',
#  'ig06hd1',
#  'g05hd2',
#  'ig06hd2',
#  'g05hd3',
#  'ig06hd3',
#  'g05hd4',
#  'ig06hd4',
#  'g05hd5',
#  'ig06hd5',
#  'g05hd6',
#  'ig06hd6',
#  'g07hd',
#  'ig08hd',
#  'ingtprhd',
#  'ingtpuhd',
#  'ingtpu01',
#  'ingtpu02',
#  'ingtpu03',
#  'ingtpu04',
#  'ingtpu05',
#  'gru11hd',
#  'gru12hd1',
#  'gru12hd2',
#  'gru13hd1',
#  'gru13hd2',
#  'gru13hd3',
#  'gru13hd4',
#  'gru14hd',
#  'gru14hd1',
#  'gru14hd2',
#  'gru14hd3',
#  'gru14hd4',
#  'gru14hd5',
#  'gru14hd6',
#  'gru21hd',
#  'gru22hd1',
#  'gru22hd2',
#  'gru23hd1',
#  'gru23hd2',
#  'gru23hd3',
#  'gru24hd',
#  'gru31hd',
#  'gru32hd1',
#  'gru32hd2',
#  'gru33hd1',
#  'gru33hd2',
#  'gru33hd3',
#  'gru34hd',
#  'gru41hd',
#  'gru42hd1',
#  'gru42hd2',
#  'gru43hd1',
#  'gru43hd2',
#  'gru43hd3',
#  'gru44hd',
#  'gru51hd',
#  'gru52hd1',
#  'gru53hd1',
#  'gru53hd2',
#  'gru53hd3',
#  'gru53hd4',
#  'gru54hd',
#  'gru61hd',
#  'gru62hd1',
#  'gru62hd2',
#  'gru63hd1',
#  'gru63hd2',
#  'gru63hd3',
#  'gru64hd',
#  'gru71hd',
#  'gru72hd1',
#  'gru72hd2',
#  'gru73hd1',
#  'gru73hd2',
#  'gru73hd3',
#  'gru74hd',
#  'gru81hd',
#  'gru82hd1',
#  'gru82hd2',
#  'gru83hd1',
#  'gru83hd2',
#  'gru83hd3',
#  'gru83hd4',
#  'gru84hd',
#  'gru84hd1',
#  'gru85hd1',
#  'gru86hd1',
#  'gru86hd2',
#  'gru87hd',
#  'ingotrhd',
#  'ingmo1hd',
#  'ingmo2hd',
#  'inghog1d',
#  'inghog2d',
#  'gashog1d',
#  'gashog21',
#  'gashog22',
#  'gashog23',
#  'gashog24',
#  'gashog26',
#  'gashog25',
#  'gashog2d',
#  'ld',
#  'estrsocial',
#  'linpe',
#  'linea',
#  'pobreza',
#  'factor07',
#  'year',
#  'mes',
#  'nconglome',
#  'conglome',
#  'vivienda',
#  'hogar',
#  'ubigeo',
#  'dominio',
#  'percepho',
#  'mieperho',
#  'totmieho',
#  'ia01hd',
#  'ia02hd',
#  'ig03hd1',
#  'ig03hd2',
#  'ig03hd3',
#  'ig03hd4',
#  'ga03hd',
#  'ga04hd',
#  'sg23',
#  'sig24',
#  'sg25',
#  'sig26',
#  'sg42',
#  'sg421',
#  'sg422',
#  'sg423',
#  'sg42d',
#  'sg42d1',
#  'sg42d2',
#  'sg42d3',
#  'ingbruhd',
#  'ingnethd',
#  'pagesphd',
#  'ingindhd',
#  'ingauthd',
#  'insedthd',
#  'insedlhd',
#  'paesechd',
#  'ingseihd',
#  'isecauhd',
#  'ingexthd',
#  'ingtrahd',
#  'ingtexhd',
#  'ingrenhd',
#  'ingoexhd',
#  'g05hd',
#  'ig06hd',
#  'g05hd1',
#  'ig06hd1',
#  'g05hd2',
#  'ig06hd2',
#  'g05hd3',
#  'ig06hd3',
#  'g05hd4',
#  'ig06hd4',
#  'g05hd5',
#  'ig06hd5',
#  'g05hd6',
#  'ig06hd6',
#  'g07hd',
#  'ig08hd',
#  'ingtprhd',
#  'ingtpuhd',
#  'ingtpu01',
#  'ingtpu02',
#  'ingtpu03',
#  'ingtpu04',
#  'ingtpu05',
#  'gru11hd',
#  'gru12hd1',
#  'gru12hd2',
#  'gru13hd1',
#  'gru13hd2',
#  'gru13hd3',
#  'gru13hd4',
#  'gru14hd',
#  'gru14hd1',
#  'gru14hd2',
#  'gru14hd3',
#  'gru14hd4',
#  'gru14hd5',
#  'gru14hd6',
#  'gru21hd',
#  'gru22hd1',
#  'gru22hd2',
#  'gru23hd1',
#  'gru23hd2',
#  'gru23hd3',
#  'gru24hd',
#  'gru31hd',
#  'gru32hd1',
#  'gru32hd2',
#  'gru33hd1',
#  'gru33hd2',
#  'gru33hd3',
#  'gru34hd',
#  'gru41hd',
#  'gru42hd1',
#  'gru42hd2',
#  'gru43hd1',
#  'gru43hd2',
#  'gru43hd3',
#  'gru44hd',
#  'gru51hd',
#  'gru52hd1',
#  'gru53hd1',
#  'gru53hd2',
#  'gru53hd3',
#  'gru53hd4',
#  'gru54hd',
#  'gru61hd',
#  'gru62hd1',
#  'gru62hd2',
#  'gru63hd1',
#  'gru63hd2',
#  'gru63hd3',
#  'gru64hd',
#  'gru71hd',
#  'gru72hd1',
#  'gru72hd2',
#  'gru73hd1',
#  'gru73hd2',
#  'gru73hd3',
#  'gru74hd',
#  'gru81hd',
#  'gru82hd1',
#  'gru82hd2',
#  'gru83hd1',
#  'gru83hd2',
#  'gru83hd3',
#  'gru83hd4',
#  'gru84hd',
#  'gru84hd1',
#  'gru85hd1',
#  'gru86hd1',
#  'gru86hd2',
#  'gru87hd',
#  'ingotrhd',
#  'ingmo1hd',
#  'ingmo2hd',
#  'inghog1d',
#  'inghog2d',
#  'gashog1d',
#  'gashog21',
#  'gashog22',
#  'gashog23',
#  'gashog24',
#  'gashog26',
#  'gashog25',
#  'gashog2d',
#  'estrsocial',
#  'ld',
#  'linpe',
#  'linea',
#  'pobreza',
#  'factor07',
#  'year',
#  'mes',
#  'conglome',
#  'vivienda',
#  'hogar',
#  'ubigeo',
#  'dominio',
#  'mieperho',
#  'totmieho',
#  'percepho',
#  'ia01hd',
#  'ia02hd',
#  'ig03hd1',
#  'ig03hd2',
#  'ig03hd3',
#  'ig03hd4',
#  'ga03hd',
#  'ga04hd',
#  'sg23',
#  'sig24',
#  'sg25',
#  'sig26',
#  'sg42',
#  'sg421',
#  'sg422',
#  'sg423',
#  'sg42d',
#  'sg42d1',
#  'sg42d2',
#  'sg42d3',
#  'ingbruhd',
#  'ingnethd',
#  'pagesphd',
#  'ingindhd',
#  'ingauthd',
#  'insedthd',
#  'insedthd1',
#  'insedlhd',
#  'paesechd',
#  'paesechd1',
#  'ingseihd',
#  'isecauhd',
#  'ingexthd',
#  'ingtrahd',
#  'ingtrahd1',
#  'ingtexhd',
#  'ingrenhd',
#  'ingoexhd',
#  'g05hd',
#  'ig06hd',
#  'g05hd1',
#  'ig06hd1',
#  'g05hd2',
#  'ig06hd2',
#  'g05hd3',
#  'ig06hd3',
#  'g05hd4',
#  'ig06hd4',
#  'g05hd5',
#  'ig06hd5',
#  'g05hd6',
#  'ig06hd6',
#  'g07hd',
#  'ig08hd',
#  'ingtprhd',
#  'ingtpuhd1',
#  'ingtpuhd',
#  'ingtpu01',
#  'ingtpu02',
#  'ingtpu021',
#  'ingtpu03',
#  'ingtpu04',
#  'ingtpu05',
#  'ingtpu06',
#  'ingtpu061',
#  'ingtpu07',
#  'ingtpu071',
#  'ingtpu08',
#  'ingtpu081',
#  'ingtpu09',
#  'ingtpu091',
#  'gru11hd',
#  'gru12hd1',
#  'gru12hd2',
#  'gru13hd1',
#  'gru13hd2',
#  'gru13hd3',
#  'gru13hd4',
#  'gru14hd',
#  'gru14hd1',
#  'gru14hd2',
#  'gru14hd3',
#  'gru14hd4',
#  'gru14hd5',
#  'gru14hd6',
#  'gru21hd',
#  'gru22hd1',
#  'gru22hd2',
#  'gru23hd1',
#  'gru23hd2',
#  'gru23hd3',
#  'gru24hd',
#  'gru31hd',
#  'gru32hd1',
#  'gru32hd2',
#  'gru33hd1',
#  'gru33hd2',
#  'gru33hd3',
#  'gru34hd',
#  'gru41hd',
#  'gru42hd1',
#  'gru42hd2',
#  'gru43hd1',
#  'gru43hd2',
#  'gru43hd3',
#  'gru44hd',
#  'gru51hd',
#  'gru52hd1',
#  'gru53hd1',
#  'gru53hd2',
#  'gru53hd3',
#  'gru53hd4',
#  'gru54hd',
#  'gru61hd',
#  'gru62hd1',
#  'gru62hd2',
#  'gru63hd1',
#  'gru63hd2',
#  'gru63hd3',
#  'gru64hd',
#  'gru71hd',
#  'gru72hd1',
#  'gru72hd2',
#  'gru73hd1',
#  'gru73hd2',
#  'gru73hd3',
#  'gru74hd',
#  'gru81hd',
#  'gru82hd1',
#  'gru82hd2',
#  'gru83hd1',
#  'gru83hd2',
#  'gru83hd3',
#  'gru83hd4',
#  'gru84hd',
#  'gru84hd1',
#  'gru85hd1',
#  'gru86hd1',
#  'gru86hd2',
#  'gru87hd',
#  'ingotrhd',
#  'ingmo1hd',
#  'ingmo2hd',
#  'inghog1d',
#  'inghog1d1',
#  'inghog2d',
#  'inghog2d1',
#  'gashog1d',
#  'gashog21',
#  'gashog22',
#  'gashog23',
#  'gashog24',
#  'gashog26',
#  'gashog25',
#  'gashog2d',
#  'estrsocial',
#  'ld',
#  'linpe',
#  'linea',
#  'pobreza',
#  'tipocuestionario',
#  'tipoentrevista',
#  'factor07',
#  'nconglome',
#  'sub_conglome',
#  'lineav_rpl',
#  'lineav',
#  'pobrezav']

# %%
# drop duplicates in a list

new_list = list(dict.fromkeys(filter_list))

# %%
len(new_list)
# Out:
# 182

# %%
new_list
# Out:
# ['c',
#  '',
#  'year',
#  'mes',
#  'nconglome',
#  'conglome',
#  'vivienda',
#  'ubigeo',
#  'dominio',
#  'percepho',
#  'gru52hd2',
#  'ingpeihd',
#  'mieperho',
#  'totmieho',
#  'ia01hd',
#  'ia02hd',
#  'ingbruhd',
#  'ingnethd',
#  'pagesphd',
#  'ingindhd',
#  'ingauthd',
#  'insedthd',
#  'insedlhd',
#  'paesechd',
#  'ingseihd',
#  'isecauhd',
#  'ingexthd',
#  'ingtrahd',
#  'ingtexhd',
#  'ingrenhd',
#  'ingoexhd',
#  'g05hd',
#  'ig06hd',
#  'g05hd1',
#  'ig06hd1',
#  'g05hd2',
#  'ig06hd2',
#  'g05hd3',
#  'ig06hd3',
#  'g05hd4',
#  'ig06hd4',
#  'g05hd5',
#  'ig06hd5',
#  'g05hd6',
#  'ig06hd6',
#  'g07hd',
#  'ig08hd',
#  'ig03hd1',
#  'ig03hd2',
#  'ig03hd3',
#  'ig03hd4',
#  'sg23',
#  'sig24',
#  'sg25',
#  'sig26',
#  'ga03hd',
#  'ga04hd',
#  'sg42',
#  'sg42d',
#  'sg421',
#  'sg42d1',
#  'sg422',
#  'sg42d2',
#  'sg423',
#  'sg42d3',
#  'ingtprhd',
#  'ingtpuhd',
#  'ingtpu01',
#  'ingtpu02',
#  'ingtpu03',
#  'ingtpu04',
#  'ingtpu05',
#  'gru11hd',
#  'gru12hd1',
#  'gru12hd2',
#  'gru13hd1',
#  'gru13hd2',
#  'gru13hd3',
#  'gru13hd4',
#  'gru14hd',
#  'gru14hd1',
#  'gru14hd2',
#  'gru14hd3',
#  'gru14hd4',
#  'gru14hd5',
#  'gru14hd6',
#  'gru21hd',
#  'gru22hd1',
#  'gru22hd2',
#  'gru23hd1',
#  'gru23hd2',
#  'gru23hd3',
#  'gru24hd',
#  'gru31hd',
#  'gru32hd1',
#  'gru32hd2',
#  'gru33hd1',
#  'gru33hd2',
#  'gru33hd3',
#  'gru34hd',
#  'gru41hd',
#  'gru42hd1',
#  'gru42hd2',
#  'gru43hd1',
#  'gru43hd2',
#  'gru43hd3',
#  'gru44hd',
#  'gru51hd',
#  'gru52hd1',
#  'gru53hd1',
#  'gru53hd2',
#  'gru53hd3',
#  'gru53hd4',
#  'gru54hd',
#  'gru61hd',
#  'gru62hd1',
#  'gru62hd2',
#  'gru63hd1',
#  'gru63hd2',
#  'gru63hd3',
#  'gru64hd',
#  'gru71hd',
#  'gru72hd1',
#  'gru72hd2',
#  'gru73hd1',
#  'gru73hd2',
#  'gru73hd3',
#  'gru74hd',
#  'gru81hd',
#  'gru82hd1',
#  'gru82hd2',
#  'gru83hd1',
#  'gru83hd2',
#  'gru83hd3',
#  'gru83hd4',
#  'gru84hd',
#  'gru84hd1',
#  'gru85hd1',
#  'gru86hd1',
#  'gru86hd2',
#  'gru87hd',
#  'ingotrhd',
#  'ingmo1hd',
#  'ingmo2hd',
#  'inghog1d',
#  'inghog2d',
#  'gashog1d',
#  'gashog2d',
#  'linpe',
#  'linea',
#  'pobreza',
#  'ld',
#  'factor07',
#  'estrsocial',
#  'hogar',
#  'gashog21',
#  'gashog22',
#  'gashog23',
#  'gashog24',
#  'gashog26',
#  'gashog25',
#  'insedthd1',
#  'paesechd1',
#  'ingtrahd1',
#  'ingtpuhd1',
#  'ingtpu021',
#  'ingtpu06',
#  'ingtpu061',
#  'ingtpu07',
#  'ingtpu071',
#  'ingtpu08',
#  'ingtpu081',
#  'ingtpu09',
#  'ingtpu091',
#  'inghog1d1',
#  'inghog2d1',
#  'tipocuestionario',
#  'tipoentrevista',
#  'sub_conglome',
#  'lineav_rpl',
#  'lineav',
#  'pobrezav']

# %%
new_list = new_list[2::] # keep interest variables

# %%
new_list
# Out:
# ['year',
#  'mes',
#  'nconglome',
#  'conglome',
#  'vivienda',
#  'ubigeo',
#  'dominio',
#  'percepho',
#  'gru52hd2',
#  'ingpeihd',
#  'mieperho',
#  'totmieho',
#  'ia01hd',
#  'ia02hd',
#  'ingbruhd',
#  'ingnethd',
#  'pagesphd',
#  'ingindhd',
#  'ingauthd',
#  'insedthd',
#  'insedlhd',
#  'paesechd',
#  'ingseihd',
#  'isecauhd',
#  'ingexthd',
#  'ingtrahd',
#  'ingtexhd',
#  'ingrenhd',
#  'ingoexhd',
#  'g05hd',
#  'ig06hd',
#  'g05hd1',
#  'ig06hd1',
#  'g05hd2',
#  'ig06hd2',
#  'g05hd3',
#  'ig06hd3',
#  'g05hd4',
#  'ig06hd4',
#  'g05hd5',
#  'ig06hd5',
#  'g05hd6',
#  'ig06hd6',
#  'g07hd',
#  'ig08hd',
#  'ig03hd1',
#  'ig03hd2',
#  'ig03hd3',
#  'ig03hd4',
#  'sg23',
#  'sig24',
#  'sg25',
#  'sig26',
#  'ga03hd',
#  'ga04hd',
#  'sg42',
#  'sg42d',
#  'sg421',
#  'sg42d1',
#  'sg422',
#  'sg42d2',
#  'sg423',
#  'sg42d3',
#  'ingtprhd',
#  'ingtpuhd',
#  'ingtpu01',
#  'ingtpu02',
#  'ingtpu03',
#  'ingtpu04',
#  'ingtpu05',
#  'gru11hd',
#  'gru12hd1',
#  'gru12hd2',
#  'gru13hd1',
#  'gru13hd2',
#  'gru13hd3',
#  'gru13hd4',
#  'gru14hd',
#  'gru14hd1',
#  'gru14hd2',
#  'gru14hd3',
#  'gru14hd4',
#  'gru14hd5',
#  'gru14hd6',
#  'gru21hd',
#  'gru22hd1',
#  'gru22hd2',
#  'gru23hd1',
#  'gru23hd2',
#  'gru23hd3',
#  'gru24hd',
#  'gru31hd',
#  'gru32hd1',
#  'gru32hd2',
#  'gru33hd1',
#  'gru33hd2',
#  'gru33hd3',
#  'gru34hd',
#  'gru41hd',
#  'gru42hd1',
#  'gru42hd2',
#  'gru43hd1',
#  'gru43hd2',
#  'gru43hd3',
#  'gru44hd',
#  'gru51hd',
#  'gru52hd1',
#  'gru53hd1',
#  'gru53hd2',
#  'gru53hd3',
#  'gru53hd4',
#  'gru54hd',
#  'gru61hd',
#  'gru62hd1',
#  'gru62hd2',
#  'gru63hd1',
#  'gru63hd2',
#  'gru63hd3',
#  'gru64hd',
#  'gru71hd',
#  'gru72hd1',
#  'gru72hd2',
#  'gru73hd1',
#  'gru73hd2',
#  'gru73hd3',
#  'gru74hd',
#  'gru81hd',
#  'gru82hd1',
#  'gru82hd2',
#  'gru83hd1',
#  'gru83hd2',
#  'gru83hd3',
#  'gru83hd4',
#  'gru84hd',
#  'gru84hd1',
#  'gru85hd1',
#  'gru86hd1',
#  'gru86hd2',
#  'gru87hd',
#  'ingotrhd',
#  'ingmo1hd',
#  'ingmo2hd',
#  'inghog1d',
#  'inghog2d',
#  'gashog1d',
#  'gashog2d',
#  'linpe',
#  'linea',
#  'pobreza',
#  'ld',
#  'factor07',
#  'estrsocial',
#  'hogar',
#  'gashog21',
#  'gashog22',
#  'gashog23',
#  'gashog24',
#  'gashog26',
#  'gashog25',
#  'insedthd1',
#  'paesechd1',
#  'ingtrahd1',
#  'ingtpuhd1',
#  'ingtpu021',
#  'ingtpu06',
#  'ingtpu061',
#  'ingtpu07',
#  'ingtpu071',
#  'ingtpu08',
#  'ingtpu081',
#  'ingtpu09',
#  'ingtpu091',
#  'inghog1d1',
#  'inghog2d1',
#  'tipocuestionario',
#  'tipoentrevista',
#  'sub_conglome',
#  'lineav_rpl',
#  'lineav',
#  'pobrezav']

# %%
panel
# Out:
#         cong  viv year_16 mes_16 nconglome_16 conglome_16 vivienda_16 hog  \
# 0     005012  039    2016     01       007083      005012         039  11
# 1     005012  025    2016     01       007083      005012         025  11
# 2     005012  012    2016     01       007083      005012         012  11
# 3     005017  075    2016     05       007093      005017         075  11
# 4     005017  008    2016     05       007093      005017         008  11
# ...      ...  ...     ...    ...          ...         ...         ...  ..
# 1934  010360  063    2016     11       008793      010360         063  11
# 1935  010360  064    2016     11       008793      010360         064  11
# 1936  010360  142    2016     11       008793      010360         142  11
# 1937  010360  144    2016     11       008793      010360         144  11
# 1938  010370  103    2016     01       044447      010370         103  11
#
#      ubigeo_16    dominio_16  ...    linea_20  pobreza_20  \
# 0       010101  sierra norte  ...  303.520996    no pobre
# 1       010101  sierra norte  ...  303.520996    no pobre
# 2       010101  sierra norte  ...  303.520996    no pobre
# 3       010101  sierra norte  ...  303.520996    no pobre
# 4       010101  sierra norte  ...  303.520996    no pobre
# ...        ...           ...  ...         ...         ...
# 1934    220504         selva  ...  247.342163    no pobre
# 1935    220504         selva  ...  247.342163    no pobre
# 1936    220504         selva  ...  247.342163    no pobre
# 1937    220504         selva  ...  247.342163    no pobre
# 1938    230101     costa sur  ...  359.276611    no pobre
#
#                                     tipocuestionario_20  tipoentrevista_20  \
# 0     cuestionario reducido - durante la emergencia ...         telefónico
# 1     cuestionario reducido - durante la emergencia ...         telefónico
# 2     cuestionario reducido - durante la emergencia ...         telefónico
# 3     cuestionario reducido - durante la emergencia ...         telefónico
# 4     cuestionario reducido - durante la emergencia ...         telefónico
# ...                                                 ...                ...
# 1934  cuestionario completo - durante la emergencia ...         presencial
# 1935  cuestionario completo - durante la emergencia ...         presencial
# 1936  cuestionario completo - durante la emergencia ...         presencial
# 1937  cuestionario completo - durante la emergencia ...         presencial
# 1938  cuestionario completo - antes de la emergencia...         presencial
#
#       factor07_20  nconglome_20  sub_conglome_20  lineav_rpl_20   lineav_20  \
# 0       39.763752        007083               00            657  553.222473
# 1       39.763752        007083               00            657  546.850037
# 2       39.763752        007083               00            657  561.609619
# 3       55.669254        007093               00            657  559.775146
# 4       55.669254        007093               00            657  563.189392
# ...           ...           ...              ...            ...         ...
# 1934   111.686325        008793               00            657  569.045166
# 1935   111.686325        008793               00            657  576.689819
# 1936   111.686325        008793               00            657  573.543945
# 1937   111.686325        008793               00            657  571.337524
# 1938     6.529222        044447               00            657  590.305908
#
#               pobrezav_20
# 0           no vulnerable
# 1           no vulnerable
# 2     vulnerable no pobre
# 3     vulnerable no pobre
# 4           no vulnerable
# ...                   ...
# 1934  vulnerable no pobre
# 1935  vulnerable no pobre
# 1936  vulnerable no pobre
# 1937        no vulnerable
# 1938        no vulnerable
#
# [1939 rows x 804 columns]

# %%
panel.columns
# Out:
# Index(['cong', 'viv', 'year_16', 'mes_16', 'nconglome_16', 'conglome_16',
#        'vivienda_16', 'hog', 'ubigeo_16', 'dominio_16',
#        ...
#        'linea_20', 'pobreza_20', 'tipocuestionario_20', 'tipoentrevista_20',
#        'factor07_20', 'nconglome_20', 'sub_conglome_20', 'lineav_rpl_20',
#        'lineav_20', 'pobrezav_20'],
#       dtype='object', length=804)

# %% [markdown]
# ## Reshape Wide to long

# %%
reshape_panel = pd.wide_to_long(panel, stubnames = new_list, i = ['cong', 'viv', 'hog'] , j = 'period' , sep = '_').reset_index()

# %%
var_labels = {"muph" : "Identificador del hogar", "unidos":"Dummy si el distrito es beneficiado por el programa"}

# %%
var_labels 

val_labels = {"unidos":{"1": "El programa si aplica en el distrito", "0": "El programa no aplica en el distrito"}}

# %%
val_labels['unidos']
# Out:
# {'1': 'El programa si aplica en el distrito',
#  '0': 'El programa no aplica en el distrito'}

# %%
reshape_panel.columns
# Out:
# Index(['cong', 'viv', 'hog', 'period', 'year', 'mes', 'nconglome', 'conglome',
#        'vivienda', 'ubigeo',
#        ...
#        'ingtpu09', 'ingtpu091', 'inghog1d1', 'inghog2d1', 'tipocuestionario',
#        'tipoentrevista', 'sub_conglome', 'lineav_rpl', 'lineav', 'pobrezav'],
#       dtype='object', length=184)

# %%
reshape_panel
# Out:
#         cong  viv hog  period  year mes nconglome conglome vivienda  ubigeo  \
# 0     005012  039  11      16  2016  01    007083   005012      039  010101
# 1     005012  039  11      17  2017  01    007083   005012      039  010101
# 2     005012  039  11      18  2018  06    007083   005012      039  010101
# 3     005012  039  11      19  2019  06    007083   005012      039  010101
# 4     005012  039  11      20  2020  06    007083   005012      039  010101
# ...      ...  ...  ..     ...   ...  ..       ...      ...      ...     ...
# 9690  010370  103  11      16  2016  01    044447   010370      103  230101
# 9691  010370  103  11      17  2017  01    044447   010370      103  230101
# 9692  010370  103  11      18  2018  02    044447   010370      103  230101
# 9693  010370  103  11      19  2019  02    044447   010370      103  230101
# 9694  010370  103  11      20  2020  02    044447   010370      103  230101
#
#       ... ingtpu09  ingtpu091     inghog1d1     inghog2d1  \
# 0     ...      NaN        NaN           NaN           NaN
# 1     ...      NaN        NaN           NaN           NaN
# 2     ...      NaN        NaN           NaN           NaN
# 3     ...      NaN        NaN           NaN           NaN
# 4     ...      0.0        0.0  36375.703125  31562.705078
# ...   ...      ...        ...           ...           ...
# 9690  ...      NaN        NaN           NaN           NaN
# 9691  ...      NaN        NaN           NaN           NaN
# 9692  ...      NaN        NaN           NaN           NaN
# 9693  ...      NaN        NaN           NaN           NaN
# 9694  ...      0.0        0.0  91723.000000  83216.000000
#
#                                        tipocuestionario  tipoentrevista  \
# 0                                                   NaN             NaN
# 1                                                   NaN             NaN
# 2                                                   NaN             NaN
# 3                                                   NaN             NaN
# 4     cuestionario reducido - durante la emergencia ...      telefónico
# ...                                                 ...             ...
# 9690                                                NaN             NaN
# 9691                                                NaN             NaN
# 9692                                                NaN             NaN
# 9693                                                NaN             NaN
# 9694  cuestionario completo - antes de la emergencia...      presencial
#
#       sub_conglome  lineav_rpl      lineav       pobrezav
# 0              NaN         NaN         NaN            NaN
# 1              NaN         NaN         NaN            NaN
# 2              NaN         NaN         NaN            NaN
# 3              NaN         NaN         NaN            NaN
# 4               00       657.0  553.222473  no vulnerable
# ...            ...         ...         ...            ...
# 9690           NaN         NaN         NaN            NaN
# 9691           NaN         NaN         NaN            NaN
# 9692           NaN         NaN         NaN            NaN
# 9693           NaN         NaN         NaN            NaN
# 9694            00       657.0  590.305908  no vulnerable
#
# [9695 rows x 184 columns]

# %% [markdown]
# # References
#
# https://docs.python.org/es/3/library/re.html
#
# https://pandas.pydata.org/docs/reference/api/pandas.wide_to_long.html
#
#
# https://pandas.pydata.org/docs/user_guide/reshaping.html
